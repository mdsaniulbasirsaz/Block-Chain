# %%
import hashlib
import time
import json
from PIL import Image
import io

# Function to generate image hash
def generate_image_hash(image_path):
    with open(image_path, "rb") as img_file:
        img_data = img_file.read()
        return hashlib.sha256(img_data).hexdigest()

# Block class
class Block:
    def __init__(self, image_hash, metadata, previous_hash):
        self.timestamp = time.time()
        self.image_hash = image_hash
        self.metadata = metadata
        self.previous_hash = previous_hash
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        data_string = json.dumps(self.metadata, sort_keys=True) + self.image_hash + str(self.timestamp) + self.previous_hash
        return hashlib.sha256(data_string.encode()).hexdigest()

# Blockchain class
class Blockchain:
    def __init__(self):
        self.chain = []
        self.create_genesis_block()

    def create_genesis_block(self):
        genesis_block = Block(
            image_hash="0",
            metadata={"description": "Genesis Block"},
            previous_hash="0"
        )
        self.chain.append(genesis_block)

    def add_block(self, image_hash, metadata):
        last_block = self.chain[-1]
        new_block = Block(image_hash, metadata, last_block.hash)
        self.chain.append(new_block)

    def verify_image(self, image_path):
        img_hash = generate_image_hash(image_path)
        for block in self.chain:
            if block.image_hash == img_hash:
                return True, block.metadata
        return False, None

# Example usage
blockchain = Blockchain()

# Adding an image to blockchain
image_path = r"C:\Users\saniu\Machine Learning 2025\Block Chain\Image.jpeg"
image_hash = generate_image_hash(image_path)
metadata = {"owner": "User1", "timestamp": time.time(), "description": "Test Image"}
blockchain.add_block(image_hash, metadata)

# Verify image integrity
is_valid, img_metadata = blockchain.verify_image(image_path)
if is_valid:
    print("Image is verified in blockchain.")
    print("Metadata:", img_metadata)
else:
    print("Image not found in blockchain.")
# Out:
# Image is verified in blockchain.
# Metadata: {'owner': 'User1', 'timestamp': 1738842843.0555696, 'description': 'Test Image'}

# %%
import hashlib
import time
import json
from PIL import Image
import io
from datetime import datetime

# Function to generate image hash
def generate_image_hash(image_path):
    with open(image_path, "rb") as img_file:
        img_data = img_file.read()
        return hashlib.sha256(img_data).hexdigest()

# Block class
class Block:
    def __init__(self, image_hash, metadata, previous_hash):
        self.timestamp = time.time()
        self.image_hash = image_hash
        self.metadata = metadata
        self.previous_hash = previous_hash
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        data_string = json.dumps(self.metadata, sort_keys=True) + self.image_hash + str(self.timestamp) + self.previous_hash
        return hashlib.sha256(data_string.encode()).hexdigest()

# Blockchain class
class Blockchain:
    def __init__(self):
        self.chain = []
        self.create_genesis_block()

    def create_genesis_block(self):
        genesis_block = Block(
            image_hash="0",
            metadata={"owner": "Genesis", "description": "Genesis Block"},
            previous_hash="0"
        )
        self.chain.append(genesis_block)

    def add_block(self, image_hash, metadata):
        last_block = self.chain[-1]
        new_block = Block(image_hash, metadata, last_block.hash)
        self.chain.append(new_block)

    def verify_image(self, image_path, owner):
        img_hash = generate_image_hash(image_path)
        for block in self.chain:
            if block.image_hash == img_hash:
                if block.metadata["owner"] == owner:
                    return True, block.metadata, "This image belongs to the given owner."
                else:
                    return True, block.metadata, f"Warning! This image belongs to {block.metadata['owner']}, not {owner}!"
        return False, None, "Image not found in blockchain."

# Example usage
blockchain = Blockchain()

# Adding images to blockchain
image_path1 = r"C:\Users\saniu\Machine Learning 2025\Block Chain\Image.jpeg"  # Replace with actual image path
image_hash1 = generate_image_hash(image_path1)
metadata1 = {"owner": "User1", "timestamp": time.time(), "description": "Test Image"}
blockchain.add_block(image_hash1, metadata1)

image_path2 = r"C:\Users\saniu\Machine Learning 2025\Block Chain\saz.jpg"  # Replace with another image path
image_hash2 = generate_image_hash(image_path2)
metadata2 = {"owner": "User2", "timestamp": time.time(), "description": "Another Test Image"}
blockchain.add_block(image_hash2, metadata2)

# Verify image and check owner
input_owner = "User1"  # Change to check with another owner
is_valid, img_metadata, message = blockchain.verify_image(image_path1, input_owner)

if is_valid:
    readable_time = datetime.fromtimestamp(img_metadata["timestamp"]).strftime('%Y-%m-%d %H:%M:%S')
    print("✅ Image is verified in blockchain.")
    print(f"🔹 Owner: {img_metadata['owner']}")
    print(f"🔹 Timestamp: {readable_time}")
    print(f"🔹 Description: {img_metadata['description']}")
    print(f"⚠ {message}")
else:
    print("❌ Image not found in blockchain.")
# Out:
# ✅ Image is verified in blockchain.
# 🔹 Owner: User1
# 🔹 Timestamp: 2025-02-06 23:23:18
# 🔹 Description: Test Image
# ⚠ This image belongs to the given owner.

# %% [markdown]
# Datasets Added:  A collection of 7.2k+ images useful for multiple use cases such image identifiers, classifier algorithms etc.https://www.kaggle.com/datasets/ashwingupta3012/human-faces?resource=download-directory

# %%
import hashlib
import time
import json
from PIL import Image
import io
from datetime import datetime
import os

# Function to generate image hash
def generate_image_hash(image_path):
    with open(image_path, "rb") as img_file:
        img_data = img_file.read()
        return hashlib.sha256(img_data).hexdigest()

# Block class
class Block:
    def __init__(self, image_hash, metadata, previous_hash):
        self.timestamp = time.time()
        self.image_hash = image_hash
        self.metadata = metadata
        self.previous_hash = previous_hash
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        data_string = json.dumps(self.metadata, sort_keys=True) + self.image_hash + str(self.timestamp) + self.previous_hash
        return hashlib.sha256(data_string.encode()).hexdigest()

# Blockchain class
class Blockchain:
    def __init__(self):
        self.chain = []
        self.create_genesis_block()

    def create_genesis_block(self):
        genesis_block = Block(
            image_hash="0",
            metadata={"owner": "Genesis", "description": "Genesis Block"},
            previous_hash="0"
        )
        self.chain.append(genesis_block)

    def add_block(self, image_hash, metadata):
        last_block = self.chain[-1]
        new_block = Block(image_hash, metadata, last_block.hash)
        self.chain.append(new_block)

    def verify_image(self, image_path, owner):
        img_hash = generate_image_hash(image_path)
        for block in self.chain:
            if block.image_hash == img_hash:
                if block.metadata["owner"] == owner:
                    return True, block.metadata, "This image belongs to the given owner."
                else:
                    return True, block.metadata, f"Warning! This image belongs to {block.metadata['owner']}, not {owner}!"
        return False, None, "Image not found in blockchain."

# Function to add all images from a dataset folder to the blockchain
def add_images_to_blockchain(blockchain, dataset_folder, default_owner="DatasetOwner"):
    # Iterate through all files in the dataset folder
    for root, dirs, files in os.walk(dataset_folder):
        for file_name in files:
            # Construct full file path
            image_path = os.path.join(root, file_name)
            
            # Generate image hash
            try:
                image_hash = generate_image_hash(image_path)

                #print the hash of the image
                print(f"Image Hash: '{file_name}': {image_hash}")
                
                # Create metadata for the image
                metadata = {
                    "owner": default_owner,
                    "timestamp": time.time(),
                    "description": f"Image: {file_name}"
                }
                
                # Add the image to the blockchain
                blockchain.add_block(image_hash, metadata)
                print(f"✅ Added image '{file_name}' to blockchain.")
            except Exception as e:
                print(f"❌ Failed to add image '{file_name}' to blockchain: {e}")

# Example usage
if __name__ == "__main__":
    # Initialize blockchain
    blockchain = Blockchain()

    # Path to your dataset folder
    dataset_folder = r"C:\Users\saniu\Machine Learning 2025\Block Chain\Humans"  # Replace with your dataset folder path

    # Add all images from the dataset folder to the blockchain
    add_images_to_blockchain(blockchain, dataset_folder, default_owner="DatasetOwner")

    # Verify an image from the dataset
    test_image_path = r"C:\Users\saniu\Machine Learning 2025\Block Chain\Humans\1 (100).jpg"
    
    input_owner = "DatasetOwner"  # Change to check with another owner

    is_valid, img_metadata, message = blockchain.verify_image(test_image_path, input_owner)
    if is_valid:
        readable_time = datetime.fromtimestamp(img_metadata["timestamp"]).strftime('%Y-%m-%d %H:%M:%S')
        print("✅ Image is verified in blockchain.")
        print(f"🔹 Owner: {img_metadata['owner']}")
        print(f"🔹 Timestamp: {readable_time}")
        print(f"🔹 Description: {img_metadata['description']}")
        print(f"⚠ {message}")
    else:
        print("❌ Image not found in blockchain.")
# Out:
# Image Hash: '1 (1).jpeg': 08a2852dae93fe5a40ffd605cd5d4cbe2fa14fb30c786dc9bd5f72f462a325bc
# ✅ Added image '1 (1).jpeg' to blockchain.
# Image Hash: '1 (1).jpg': 8a34e7110637bd47315f85bc7edfbc55165d6513a3378306ea6118d8d020681a
# ✅ Added image '1 (1).jpg' to blockchain.
# Image Hash: '1 (1).png': be1a8cd417bb203247fa6da4ab91215125b46b62b75ff8d9753db6f84c9e58ad
# ✅ Added image '1 (1).png' to blockchain.
# Image Hash: '1 (10).jpeg': bd6f40c495926182419a20032800d2ee53da2899f45dc21eee11f6ee123b1fef
# ✅ Added image '1 (10).jpeg' to blockchain.
# Image Hash: '1 (10).jpg': 6ce0f0475e207310878ddc18a53dca5a223a935d99239549ff749cbf0c1c0043
# ✅ Added image '1 (10).jpg' to blockchain.
# Image Hash: '1 (10).png': df45bf6e3b23d5c036f1dbd8e63f3dc73cf5a23e88e1452c9929aa282027f678
# ✅ Added image '1 (10).png' to blockchain.
# Image Hash: '1 (100).jpg': d1081e97902cb812c28094c5673445f2011caa2dc77eac2125229ae72bc0b421
# ✅ Added image '1 (100).jpg' to blockchain.
# Image Hash: '1 (100).png': 3cb2dfb5a3e6bac7f57211d0011159a96ba48fc945f41ca5ead6247882ffa6f1
# ✅ Added image '1 (100).png' to blockchain.
# Image Hash: '1 (1000).jpg': 0995e6a0b646111b13d889929d00f6512c725336e181d65c9af7c7f5911e63f1
# ✅ Added image '1 (1000).jpg' to blockchain.
# Image Hash: '1 (1001).jpg': ec3f496738a9e12bb26fd71bdb26fd0d14e78b84aae0f123f6e8b3cff42f83f5
# Image Hash: '1 (1192).jpg': f3204c46aa0e571d403b911f5627dd42880901d242112471253981f02705ba57
# ✅ Added image '1 (1192).jpg' to blockchain.
# Image Hash: '1 (1193).jpg': 88f53872bf7b113c511c4df570b5baff6cb01231c2d7eab7ba7f92f5080e1a69
# ✅ Added image '1 (1193).jpg' to blockchain.
# Image Hash: '1 (1194).jpg': 6ea705bfb8946aa8e06300a9ba7b11299acd2018a7be6a0e46f7cf03197fa52d
# ✅ Added image '1 (1194).jpg' to blockchain.
# Image Hash: '1 (1195).jpg': afbb46d903905b3aaf85fc53f74da0756c14a4abea0798a1f109a91409834a49
# ✅ Added image '1 (1195).jpg' to blockchain.
# Image Hash: '1 (1196).jpg': 69e6e4ccab56fb4cc9f87ad034f1fcb5d7197a21b50ef20a3838d6e9fdbefe92
# ✅ Added image '1 (1196).jpg' to blockchain.
# Image Hash: '1 (1197).jpg': e5dd27306f85a9c91de832c9ece41f26c6854980b84bfb04d9d057a1a495d5b6
# ✅ Added image '1 (1197).jpg' to blockchain.
# Image Hash: '1 (1198).jpg': c030b3cee281be295a151693800e50905449c26287ff973a401c885ac4a4b154
# ✅ Added image '1 (1198).jpg' to blockchain.
# Image Hash: '1 (1199).jpg': ff667519438afcc2b30ad6940e26001ec2b823506d778838461876cc1ae07842
# ✅ Added image '1 (1199).jpg' to blockchain.
# Image Hash: '1 (12).jpeg': b8d9761fb4f561505ed37703dc9d2fe15b20f7956b2200feb2dda12abbf8f282
# ✅ Added image '1 (12).jpeg' to blockchain.
# Image Hash: '1 (12).jpg': 3a3a1379267c68919bfe45d7140c66efaf4818f2d4f98e257acbab50e7df56aa
# ✅ Added image '1 (12).jpg' to blockchain.
# Image Hash: '1 (12).png': 1a238bf15a3dce701f2fcdaa68b5f27ad27c87302798a3c9871b4477728c230a
# ✅ Added image '1 (12).png' to blockchain.
# Image Hash: '1 (120).jpg': 8bb46bb768f3b4a62f4cdafabbf058f6dd62d1e072cfc73d8233d9d61c121877
# ✅ Added image '1 (120).jpg' to blockchain.
# Image Hash: '1 (120).png': 83618dfcd37792f78d66feddbd44083598032a3cf4e737b1bfebeaa3ed6dcb31
# ✅ Added image '1 (120).png' to blockchain.
# Image Hash: '1 (1200).jpg': 7d4a839aba431d6660e7e723b8b4e2e51edd23950c8d7d787b627551d351a66f
# ✅ Added image '1 (1200).jpg' to blockchain.
# Image Hash: '1 (1201).jpg': 768896bd37911b7b8828327d806b7380e3c5f90dcd579855dab81acd5eb1a4d0
# ✅ Added image '1 (1201).jpg' to blockchain.
# Image Hash: '1 (1202).jpg': 0e7282d1efc0e288127e78fadb88c79c9efc1289d623ae5820e40f93b2777a0d
# ✅ Added image '1 (1202).jpg' to blockchain.
# Image Hash: '1 (1203).jpg': 7d4a839aba431d6660e7e723b8b4e2e51edd23950c8d7d787b627551d351a66f
# ✅ Added image '1 (1203).jpg' to blockchain.
# Image Hash: '1 (1204).jpg': 90cd715535ec01e7ad5bfd66c55835f36f45894a9cd5fd56723c0b0bd5928a2e
# ✅ Added image '1 (1204).jpg' to blockchain.
# Image Hash: '1 (128).jpg': 9576da744d96eb4bd1037d86055d5d173a137b3944da7cfa06ad7b287e3a40f0
# ✅ Added image '1 (128).jpg' to blockchain.
# Image Hash: '1 (128).png': 5acc9207052eb427527d038bad7d585e1633164ec6c39c28b979b1cc3bd98dfe
# ✅ Added image '1 (128).png' to blockchain.
# Image Hash: '1 (1280).jpg': 4046a4dba654529f2264beb639036bf33fb1261d8757b01b4f3e9e626a28d2a3
# ✅ Added image '1 (1280).jpg' to blockchain.
# ...
# ✅ Added image '1 (900).jpg' to blockchain.
# Image Hash: '1 (901).jpg': c76e3f3b76023b45e0e01f3de98d04edcc25b6d3b5dbfe9d1aded51e2c9796ef
# ✅ Added image '1 (901).jpg' to blockchain.
# Image Hash: '1 (902).jpg': 525d654f8ab1c93c9c8f44ae6532cb31c01491e0a20efa81fcd022904ab7ac3e
# ✅ Added image '1 (902).jpg' to blockchain.
# Image Hash: '1 (903).jpg': e6e8db540be78b2df1268059a1d8d49a66585c4b7edf350c07a4d865c8d33618
# ✅ Added image '1 (903).jpg' to blockchain.
# Image Hash: '1 (904).jpg': 1dd78b9f22670892df6f75271e9f663424461258d5b1b909424db71774e3a078
# ✅ Added image '1 (904).jpg' to blockchain.
# Image Hash: '1 (905).jpg': 86e3e2f95c5e919e968fb2f530e82a12db428ea381e1b731f092f5c67fb6f650
# ✅ Added image '1 (905).jpg' to blockchain.
# Image Hash: '1 (906).jpg': e2b164451ac5686ae8c22897b8e1c5b22b012040e63ed57c4fde8ff3ecf92c77
# ✅ Added image '1 (906).jpg' to blockchain.
# Image Hash: '1 (907).jpg': d67ec8057f26cabb7112455337f1e83d42bf755b18d7eb08a0a8fc39ac033194
# ✅ Added image '1 (907).jpg' to blockchain.
# Image Hash: '1 (908).jpg': c0376f61426b09251ededf8a8375750afe6b2e576dc81cd53f26f19791e4e3d0
# ✅ Added image '1 (908).jpg' to blockchain.
# Image Hash: '1 (909).jpg': 1bea99c54a1d1f2df09e26bfbdbf5007aa1e508f849a2760d53e280630ecc699
# ✅ Added image '1 (909).jpg' to blockchain.
# Image Hash: '1 (91).jpg': 3967e873e22ecb0b1dadab10a6ed500827acfeccfacd394681b21ce8f6fcdd75
# ✅ Added image '1 (91).jpg' to blockchain.
# Image Hash: '1 (91).png': 83618dfcd37792f78d66feddbd44083598032a3cf4e737b1bfebeaa3ed6dcb31
# ✅ Added image '1 (91).png' to blockchain.
# Image Hash: '1 (910).jpg': f22f3e0083ac8253571a3e584ca74982731c0b0b5ee846536d3603988ce11450
# ✅ Added image '1 (910).jpg' to blockchain.
# Image Hash: '1 (911).jpg': a9f0548fd39f38109643cb58e6dac1fc63199e05acd68942d9fc3de0b77a0d77
# ✅ Added image '1 (911).jpg' to blockchain.
# Image Hash: '1 (912).jpg': 87ee1156cb55e5d61a415a27838fed6c0d4093a9850aabbc800377c4eb738077
# ✅ Added image '1 (912).jpg' to blockchain.
# Image Hash: '1 (913).jpg': f585508124235b9f3ed7d4ff0cb684acbfc8fe3973622da7dc65817b729e65c2
# ✅ Added image '1 (913).jpg' to blockchain.
# Image Hash: '1 (93).jpg': 04527fcfe3b17c3df20608a7e2cb5857f907c5ac36b42a3a9b24b01bb1116c9b
# ✅ Added image '1 (93).jpg' to blockchain.
# Image Hash: '1 (93).png': d8963ab262e7f96442640bc3adaabf9f27050a600cb28e6f15c5a1fbee5acc6a
# ✅ Added image '1 (93).png' to blockchain.
# Image Hash: '1 (930).jpg': 549ca248713487c9f728242e986ae46cf74fee251ab4776f2e20ec08f0a8f348
# ✅ Added image '1 (930).jpg' to blockchain.
# Image Hash: '1 (931).jpg': 33176ca837964e9641daa62812b4bff0d60af7dbc1a74f8fb35dbebb74e6246d
# ✅ Added image '1 (931).jpg' to blockchain.
# Image Hash: '1 (932).jpg': 7995a58f3006c2bab66a836c6c5c3774a4910570335fa14b8e15d03833d034aa
# ✅ Added image '1 (932).jpg' to blockchain.
# Image Hash: '1 (933).jpg': 497a3e5776251be1f910fcb00dfd03bcf2b1d317c13315396f8c848de41b94cf
# ✅ Added image '1 (933).jpg' to blockchain.
# Image Hash: '1 (934).jpg': 15dff03e5f7989c910b3d0d66db123711a7d88405f9d3c25163f4fa0b54cc91f
# ✅ Added image '1 (934).jpg' to blockchain.
# Image Hash: '1 (935).jpg': fb0e35a5d5f867ccddc8bf76b43c5c4d5013503721ca415fcfda77b7264a3427
# ✅ Added image '1 (935).jpg' to blockchain.
# Image Hash: '1 (936).jpg': 79adc0dc53700e62700cd063dcba5ddeb3990a201f48a999cdeec86ca7622e9d
# ✅ Added image '1 (936).jpg' to blockchain.
# Image Hash: '1 (937).jpg': 7d091dc5221d47c028fc654d12781c19a2cd76d03b86ea1278a483a6341279f0
# ✅ Added image '1 (937).jpg' to blockchain.
# Image Hash: '1 (938).jpg': b74dd8e0c9e7372dbf65bc2592676b623cb321d516b891a82f843dc45a68e24c
# ✅ Added image '1 (938).jpg' to blockchain.
# Image Hash: '1 (939).jpg': f58466d6343bd893b78dadb7e4745aeb8ba4864118e0c939bf0fab9dbe4e9866
# ✅ Added image '1 (939).jpg' to blockchain.
# Image Hash: '1 (94).jpg': a897d960f11c41bc2008e586eeeb29974481431009cef8ab1b5e482aa861a1eb
# ✅ Added image '1 (94).jpg' to blockchain.
# Image Hash: '1 (94).png': 95976e9de4cad4ef216c0d500867abdcd5729f8c76193babfb4f4432c7cc822e
# ✅ Added image '1 (94).png' to blockchain.
# Image Hash: '1 (940).jpg': 51aaa824c3ea89950cfa40fd6c185f662a32610f212e72f5956827f6a242bde7
# ✅ Added image '1 (940).jpg' to blockchain.
# Image Hash: '1 (941).jpg': f9cc82197448bc6bdf7a60f7713300711c0b7cc48d6b3c1cc22985956a323727
# ✅ Added image '1 (941).jpg' to blockchain.
# Image Hash: '1 (942).jpg': bb899d5a83135a8bd64a80df4440f49e75b178fae4408744f24e5baa6dab5bcb
# ✅ Added image '1 (942).jpg' to blockchain.
# Image Hash: '1 (943).jpg': 1719112c6fc1165832521c7fe49d9d3fe5702fd5b7dccd3895c63be0a0e00f01
# ✅ Added image '1 (943).jpg' to blockchain.
# ✅ Added image '1 (974).jpg' to blockchain.
# Image Hash: '1 (975).jpg': 923c34b34dc907b41556d049080ab698520b5f1d1cb408f596298b31097aae40
# ✅ Added image '1 (975).jpg' to blockchain.
# Image Hash: '1 (976).jpg': f4d4b3fcb53f94e7a5c1c2b7aa86a0a1051e0f22e3b26e9e5025762de14959d5
# ✅ Added image '1 (976).jpg' to blockchain.
# Image Hash: '1 (977).jpg': ed8e3ebef6eb069eb077ee82e6a1a85cc9465ff5cc920f87887a7bca77744306
# ✅ Added image '1 (977).jpg' to blockchain.
# Image Hash: '1 (978).jpg': 3a3a1379267c68919bfe45d7140c66efaf4818f2d4f98e257acbab50e7df56aa
# ✅ Added image '1 (978).jpg' to blockchain.
# Image Hash: '1 (979).jpg': 7f72b82cbc908b3dc27eead22cfa3430c146274f2beb8c1194cd87bd8dce4abf
# ✅ Added image '1 (979).jpg' to blockchain.
# Image Hash: '1 (98).jpg': 04527fcfe3b17c3df20608a7e2cb5857f907c5ac36b42a3a9b24b01bb1116c9b
# ✅ Added image '1 (98).jpg' to blockchain.
# Image Hash: '1 (98).png': 700c3af705c5515239d3d86b650d53c329874aa51bf99c9c4e42d6bd0df5a159
# ✅ Added image '1 (98).png' to blockchain.
# Image Hash: '1 (980).jpg': 62a6eeb75830fc2439296b119ac5e6713ec067002125b186105c97fc6eb68a9c
# ✅ Added image '1 (980).jpg' to blockchain.
# Image Hash: '1 (981).jpg': f2c1607a3427dcf76c8b8489cb116c5c32397e738b940ed78227f0b1512cbd49
# ✅ Added image '1 (981).jpg' to blockchain.
# Image Hash: '1 (982).jpg': 8e5e995e610f0841a5f63b218cd8614719992a1bdf7513d1121f9898e8ded546
# ✅ Added image '1 (982).jpg' to blockchain.
# Image Hash: '1 (983).jpg': e4acc29d88a2c6982fe295b50109e4c4c50be93f31bdcedbdf26b783b406efb6
# ✅ Added image '1 (983).jpg' to blockchain.
# Image Hash: '1 (984).jpg': a07d195a748624fbd381f633137cf2579c3784795bf5ef7a48437f408733ae46
# ✅ Added image '1 (984).jpg' to blockchain.
# Image Hash: '1 (985).jpg': 768896bd37911b7b8828327d806b7380e3c5f90dcd579855dab81acd5eb1a4d0
# ✅ Added image '1 (985).jpg' to blockchain.
# Image Hash: '1 (986).jpg': eb7b97305ba15e8471684a710aa8ad9d509775bb1d130bbd25a5abe746f915cd
# ✅ Added image '1 (986).jpg' to blockchain.
# Image Hash: '1 (987).jpg': aae54e572db85dfa80257da2e18a6d87b00c1f998a43a0bb434c41280f5d4d9e
# ✅ Added image '1 (987).jpg' to blockchain.
# Image Hash: '1 (988).jpg': 6226310f0020448cec124e64b58239abffb1388cced9ae74dfd8e9b65527a059
# ✅ Added image '1 (988).jpg' to blockchain.
# Image Hash: '1 (989).jpg': dfc7a628b742e52b08da8203e055b096eae467783b7686814a9faf8d228b7dd0
# ✅ Added image '1 (989).jpg' to blockchain.
# Image Hash: '1 (99).jpg': 0e7282d1efc0e288127e78fadb88c79c9efc1289d623ae5820e40f93b2777a0d
# ✅ Added image '1 (99).jpg' to blockchain.
# Image Hash: '1 (99).png': 7f4181ff68239999302e9bafe7ee5f92b8c39a5049c654d33abb93133fb623dc
# ✅ Added image '1 (99).png' to blockchain.
# Image Hash: '1 (990).jpg': 384bfb2faa78ea128fe7b1e750838db1ab66c282683a7e29a42d2ef40346d718
# ✅ Added image '1 (990).jpg' to blockchain.
# Image Hash: '1 (991).jpg': 000378c1d10174b464cce1529565dbc5fc9a0d45d4d175cd88ee075bd6ecde6e
# ✅ Added image '1 (991).jpg' to blockchain.
# Image Hash: '1 (992).jpg': 12276baf86140bdd5a2b09b352e8dc29b0d90c5efc27bd28ecd68ad6cfa58c46
# ✅ Added image '1 (992).jpg' to blockchain.
# Image Hash: '1 (993).jpg': 1d9a6fc7ebc490d81b6142721e2e88970b04743f76d68a2bc269507f4f0c24ce
# ✅ Added image '1 (993).jpg' to blockchain.
# Image Hash: '1 (994).jpg': 4fad9873b7c4fa69ada0bf4a68ec5bd00a4349767a0152a93ed55f0334aa970a
# ✅ Added image '1 (994).jpg' to blockchain.
# Image Hash: '1 (995).jpg': e01e961629adedf541f6365c56aade74e69ce02c5a97e41989a962f8878ee662
# ✅ Added image '1 (995).jpg' to blockchain.
# Image Hash: '1 (996).jpg': cc536255adc67294a44283fb8c0e370776b6bc2fe6a89c1c0cf22f4ba36577be
# ✅ Added image '1 (996).jpg' to blockchain.
# Image Hash: '1 (997).jpg': 5a31148ac5a0aa123adce5f2ea828b29e8bf94d446efa7e9433c4d16128de9b7
# ✅ Added image '1 (997).jpg' to blockchain.
# Image Hash: '1 (998).jpg': 525d654f8ab1c93c9c8f44ae6532cb31c01491e0a20efa81fcd022904ab7ac3e
# ✅ Added image '1 (998).jpg' to blockchain.
# Image Hash: '1 (999).jpg': 838279eb1e749beab6f2506aaffb8c4f5d4b066a8b35c8779aa0e5a5d510f368
# ✅ Added image '1 (999).jpg' to blockchain.
# ✅ Image is verified in blockchain.
# 🔹 Owner: DatasetOwner
# 🔹 Timestamp: 2025-02-07 00:51:50
# 🔹 Description: Image: 1 (100).jpg
# ⚠ This image belongs to the given owner.

# %% [markdown]
# # Storing Blockchain Image Hashes in MongoDB
#
# MongoDB is a NoSQL database that supports flexible data structures. It can be a suitable choice for storing blockchain data, such as image hashes and metadata. In this notebook, we will demonstrate how to integrate MongoDB for storing blockchain image hashes.

# %%
import hashlib
import time
import json
from PIL import Image
import os
from pymongo import MongoClient  # MongoDB library

# MongoDB connection setup
def connect_to_mongodb():
    try:
        client = MongoClient("mongodb+srv://saniulsaz:12345@roktodin.abnxvco.mongodb.net/")  # MongoDB server address
        db = client["blockchain_db"]  # Database name
        collection = db["images"]  # Collection name
        print("✅ Connected to MongoDB.")
        return collection
    except Exception as e:
        print(f"❌ Failed to connect to MongoDB: {e}")
        return None

# Function to generate image hash
def generate_image_hash(image_path):
    try:
        if not os.path.isfile(image_path):  # Check if the file exists
            print(f"❌ File '{image_path}' does not exist.")
            return None

        file_size = os.path.getsize(image_path)
        if file_size == 0:  # Check if the file is empty
            print(f"❌ File '{image_path}' is empty.")
            return None

        with open(image_path, "rb") as img_file:
            img_data = img_file.read()
            return hashlib.sha256(img_data).hexdigest()
    except Exception as e:
        print(f"❌ Error reading file '{image_path}': {e}")
        return None

# Block class
class Block:
    def __init__(self, image_hash, metadata, previous_hash):
        self.timestamp = time.time()
        self.image_hash = image_hash
        self.metadata = metadata
        self.previous_hash = previous_hash
        self.hash = self.calculate_hash()

    def calculate_hash(self):
        data_string = json.dumps(self.metadata, sort_keys=True) + self.image_hash + str(self.timestamp) + self.previous_hash
        return hashlib.sha256(data_string.encode()).hexdigest()

    def to_dict(self):
        # Convert block to a dictionary for MongoDB insertion
        return {
            "timestamp": self.timestamp,
            "image_hash": self.image_hash,
            "metadata": self.metadata,
            "previous_hash": self.previous_hash,
            "hash": self.hash
        }

# Blockchain class
class Blockchain:
    def __init__(self, mongo_collection):
        self.chain = []
        self.mongo_collection = mongo_collection  # MongoDB collection
        self.create_genesis_block()

    def create_genesis_block(self):
        genesis_block = Block(
            image_hash="0",
            metadata={"owner": "Genesis", "description": "Genesis Block"},
            previous_hash="0"
        )
        self.chain.append(genesis_block)
        self.save_block_to_mongodb(genesis_block)

    def add_block(self, image_hash, metadata):
        last_block = self.chain[-1]
        new_block = Block(image_hash, metadata, last_block.hash)
        self.chain.append(new_block)
        self.save_block_to_mongodb(new_block)

    def save_block_to_mongodb(self, block):
        # Save block to MongoDB
        block_dict = block.to_dict()
        try:
            self.mongo_collection.insert_one(block_dict)
            print(f"✅ Saved block with hash '{block.hash}' to MongoDB.")
        except Exception as e:
            print(f"❌ Failed to save block to MongoDB: {e}")

    def verify_image(self, image_path, owner):
        img_hash = generate_image_hash(image_path)
        if img_hash is None:
            print(f"❌ Unable to generate hash for image: {image_path}")
            return False, None, "Failed to generate image hash."

        for block in self.chain:
            if block.image_hash == img_hash:
                if block.metadata["owner"] == owner:
                    return True, block.metadata, "This image belongs to the given owner."
                else:
                    return True, block.metadata, f"Warning! This image belongs to {block.metadata['owner']}, not {owner}!"
        return False, None, "Image not found in blockchain."

# Function to check if the file is a supported image format
def is_supported_image(file_name):
    supported_extensions = [".jpg", ".jpeg", ".png"]
    ext = os.path.splitext(file_name)[1].lower()
    return ext in supported_extensions

# Function to add all images from a dataset folder to the blockchain
def add_images_to_blockchain(blockchain, dataset_folder, default_owner="DatasetOwner"):
    for root, dirs, files in os.walk(dataset_folder):
        for file_name in files:
            if not is_supported_image(file_name):
                print(f"⚠ Skipping unsupported file: {file_name}")
                continue

            image_path = os.path.join(root, file_name)
            try:
                image_hash = generate_image_hash(image_path)
                if image_hash is None:
                    print(f"❌ Skipping invalid image: {file_name}")
                    continue

                print(f"🔍 Hash for '{file_name}': {image_hash}")

                metadata = {
                    "owner": default_owner,
                    "timestamp": time.time(),
                    "description": f"Image: {file_name}"
                }

                blockchain.add_block(image_hash, metadata)
                print(f"✅ Added image '{file_name}' to blockchain.")
            except Exception as e:
                print(f"❌ Failed to add image '{file_name}' to blockchain: {e}")


# New function to check any image
def check_image_in_blockchain(blockchain, image_path, owner):
    print(f"🔍 Checking image: {image_path}")
    is_valid, img_metadata, message = blockchain.verify_image(image_path, owner)
    if is_valid:
        readable_time = datetime.fromtimestamp(img_metadata["timestamp"]).strftime('%Y-%m-%d %H:%M:%S')
        print("✅ Image is verified in blockchain.")
        print(f"🔹 Owner: {img_metadata['owner']}")
        print(f"🔹 Timestamp: {readable_time}")
        print(f"🔹 Description: {img_metadata['description']}")
        print(f"⚠ {message}")
    else:
        print("❌ Image not found in blockchain.")

# Example usage
if __name__ == "__main__":
    # Connect to MongoDB
    mongo_collection = connect_to_mongodb()
    if mongo_collection is None:
        print("❌ Exiting due to MongoDB connection failure.")
        exit(1)

    # Initialize blockchain
    blockchain = Blockchain(mongo_collection)

    # Path to your dataset folder
    dataset_folder = r"C:\Users\saniu\Machine Learning 2025\Block Chain\Humans"  # Replace with your dataset folder path

    # Add all images from the dataset folder to the blockchain
    add_images_to_blockchain(blockchain, dataset_folder, default_owner="DatasetOwner")

    # Check an image using the new function
    test_image_path = r"C:\Users\saniu\Machine Learning 2025\Block Chain\Humans\1 (100).jpg"
    input_owner = "DatasetOwner"  # Change to check with another owner
    check_image_in_blockchain(blockchain, test_image_path, input_owner)
# Out:
# ✅ Connected to MongoDB.
# ✅ Saved block with hash '2387e05825f57d664b7faf83c3fc9efa678ca9c0081ce6bb5384ff39765b49bb' to MongoDB.
# 🔍 Hash for '1 (1).jpeg': 08a2852dae93fe5a40ffd605cd5d4cbe2fa14fb30c786dc9bd5f72f462a325bc
# ✅ Saved block with hash '9211466dc853035e4f7eb89233416d7c51f5713fc2054d6b7e26f5b6112ff5d4' to MongoDB.
# ✅ Added image '1 (1).jpeg' to blockchain.
# 🔍 Hash for '1 (1).jpg': 8a34e7110637bd47315f85bc7edfbc55165d6513a3378306ea6118d8d020681a
# ✅ Saved block with hash '0ab604dbf90630bb99756c01973931942d2cf1f9de0fc5cdc8d5cbc0a9426a21' to MongoDB.
# ✅ Added image '1 (1).jpg' to blockchain.
# 🔍 Hash for '1 (1).png': be1a8cd417bb203247fa6da4ab91215125b46b62b75ff8d9753db6f84c9e58ad
# ✅ Saved block with hash '401ed594693936b711b90525c20ba1e7a673de292616afe450d7e5ec63f4fb67' to MongoDB.
# ✅ Added image '1 (1).png' to blockchain.
# 🔍 Hash for '1 (10).jpeg': bd6f40c495926182419a20032800d2ee53da2899f45dc21eee11f6ee123b1fef
# ✅ Saved block with hash 'c7e9007383cf7fd3d3cc1ba1108f665aa50f45b0bd00530f0eefc950a87eceb8' to MongoDB.
# ✅ Added image '1 (10).jpeg' to blockchain.
# 🔍 Hash for '1 (10).jpg': 6ce0f0475e207310878ddc18a53dca5a223a935d99239549ff749cbf0c1c0043
# ✅ Saved block with hash '62d8f640df99ac9977b03f46bebbaec50a46aad26ac1cfa478c6f89c2a8c18b7' to MongoDB.
# ✅ Added image '1 (10).jpg' to blockchain.
# 🔍 Hash for '1 (10).png': df45bf6e3b23d5c036f1dbd8e63f3dc73cf5a23e88e1452c9929aa282027f678
# ✅ Saved block with hash '52f8ceb4279bdd1d5ad368a71e54cbdbbb163ef6bdcff4235c752fe3300cb5f1' to MongoDB.
# ✅ Added image '1 (10).png' to blockchain.
# 🔍 Hash for '1 (100).jpg': d1081e97902cb812c28094c5673445f2011caa2dc77eac2125229ae72bc0b421
# ✅ Saved block with hash '49eb68933db04cc24345983cf6c92a3b70d1b30512a190d263deb3e39698792e' to MongoDB.
# ✅ Added image '1 (100).jpg' to blockchain.
# 🔍 Hash for '1 (100).png': 3cb2dfb5a3e6bac7f57211d0011159a96ba48fc945f41ca5ead6247882ffa6f1
# ✅ Saved block with hash '823929298ab1c6c8cf9c97a645824bd904758d99460f16aabe48c2a43fd43b05' to MongoDB.
# ✅ Added image '1 (100).png' to blockchain.
# 🔍 Hash for '1 (1000).jpg': 0995e6a0b646111b13d889929d00f6512c725336e181d65c9af7c7f5911e63f1
# ✅ Saved block with hash '0385d9506e8a11edb25133ebb44dcc82c8ceb3fcd19f7c5ee6a38c56122f2957' to MongoDB.
# ✅ Added image '1 (1000).jpg' to blockchain.
# 🔍 Hash for '1 (1001).jpg': ec3f496738a9e12bb26fd71bdb26fd0d14e78b84aae0f123f6e8b3cff42f83f5
# ✅ Saved block with hash '311171a6a4ed1ab29003fae3be1eceecc48cffcef87d34faff5d92f2ba5bc93c' to MongoDB.
# ✅ Added image '1 (1001).jpg' to blockchain.
# 🔍 Hash for '1 (1002).jpg': 95b3fec62d4db7e60131e164590cfc3cea644623137dac020502c1c597d3d207
# ✅ Saved block with hash '675d63bebbb84103203f584e7e8d02c123e5289e86d25892ca3b3abd94b0a030' to MongoDB.
# ✅ Added image '1 (1002).jpg' to blockchain.
# 🔍 Hash for '1 (1003).jpg': 008afd38905d171aecd1b47378d812cba316915a3ac9e61de3f7927015696e67
# ✅ Saved block with hash '32fdb62d39cd992b96407383bf9422ec4b0d4849b807860c38cf024a502ace52' to MongoDB.
# ✅ Added image '1 (1003).jpg' to blockchain.
# 🔍 Hash for '1 (1004).jpg': a872a50d85cf0d266078759f8a45fcf41f290fb36760faa283954f0dd0cf5ea7
# ✅ Saved block with hash 'a8881c56b1fe49e4f1c9c923a82766a878e475b310302122d412342457dcdad5' to MongoDB.
# ✅ Added image '1 (1004).jpg' to blockchain.
# 🔍 Hash for '1 (1005).jpg': e3246aca81ce83446aaf2622fe5c4f1f54071808c4de3aac42b8507e9b5a36a5
# ✅ Saved block with hash '613adacd61a301fba7f92d86eb1fb4c7bcb7efce54bc813f2e2f99b2d4ee8104' to MongoDB.
# ✅ Added image '1 (1005).jpg' to blockchain.
# 🔍 Hash for '1 (1006).jpg': 35aa30b5c4e3f384b52b4787ad1277caddeb3f59e741c139442eb345a056a368
# ✅ Saved block with hash '93cdaf37ffe754894502c9eb6feb2efcc183bfd4f9ea9b4784ae145e1e10d8a8' to MongoDB.
# ✅ Added image '1 (1006).jpg' to blockchain.
# 🔍 Hash for '1 (1007).jpg': 036dd2511402979020af1d9a615e90726f139362d78e1b1b1716c7edce0e5061
# ✅ Saved block with hash 'ab29782c511743280d8091c3d5fdc351857888f6a4604ad1427e26e2990645a0' to MongoDB.
# ✅ Added image '1 (1007).jpg' to blockchain.
# 🔍 Hash for '1 (1008).jpg': 3206e85c5900efa2888dc91905be5370deab538dbb71fc04186cfd6a5c386e4c
# ✅ Saved block with hash '3b9b7eb0db7f0803c27ee2469fbed40b65c0d57eaa6e7ce3e9960486b34f4402' to MongoDB.
# ✅ Added image '1 (1008).jpg' to blockchain.
# 🔍 Hash for '1 (1009).jpg': d46595433317a469ecd2b5fcb22b5d0b2972f97a66302f5f839c796d1fdaaf2e
# ✅ Saved block with hash 'fec5c892946930ba1b38cfc89a98517ae7fc0b556e39c5167fbdf47ff383cf37' to MongoDB.
# ✅ Added image '1 (1009).jpg' to blockchain.
# 🔍 Hash for '1 (101).jpg': ce4104ce62b98a5b4f8428542be73b70cd4bd9bbe86ec32719c1230ceadd2bfa
# ✅ Saved block with hash 'c89dbb5801240fa4ea65a5d436c719833345a87685d0fce8e0f3226c3bc74b7c' to MongoDB.
# ✅ Added image '1 (101).jpg' to blockchain.
# 🔍 Hash for '1 (101).png': 0b7443d7327c20617d683e5ee8996fb10928b5d75bcce9a35947ca0d68e5676d
# ✅ Saved block with hash '84deba22fdb664baeaa2681ace1dcdc15f15e01b9bdd04299f98e0431c18a4e8' to MongoDB.
# ✅ Added image '1 (101).png' to blockchain.
# 🔍 Hash for '1 (1010).jpg': 9cc00d2c74e510a202bf0956ee1b168ca618d5442a37dececfed7f9308732703
# ✅ Saved block with hash '2aeceb4fbb7a93b32f04cc13e6a413a70acbaf7ba1c67d34cc2c29952ffe3ab8' to MongoDB.
# ✅ Added image '1 (1010).jpg' to blockchain.
# 🔍 Hash for '1 (1011).jpg': 7620fc7cfca2ff10c781793f442e4d47f2544094a5a0decb0a1013604eb0ad8e
# ✅ Saved block with hash 'f11f4f3fc30516676c6e7df336bf8808040edb8bf682dd2e52ba5cfbcc6a6b85' to MongoDB.
# ✅ Added image '1 (1011).jpg' to blockchain.
# 🔍 Hash for '1 (1012).jpg': ec0d48de54cfa99ce908ce6ebe7f2f5c7b68d5e3ddc80d645608c94a60b44aad
# ✅ Saved block with hash '02aa931cbb9c447125a43b1a5fe7164e9e54b4087ade72e73d2230cc41d83a06' to MongoDB.
# ✅ Added image '1 (1012).jpg' to blockchain.
# 🔍 Hash for '1 (1013).jpg': 2362c7a0407d715fca5f3affa60ec6e8ec36f4d85f5f48cc75da40a80a73810a
# ✅ Saved block with hash '4343d01d3e21a258214e0fe016e23fd3c8b8c03a8d399acde44db8bdea2d9c51' to MongoDB.
# ✅ Added image '1 (1013).jpg' to blockchain.
# 🔍 Hash for '1 (1014).jpg': d74052c7093ad6f358ad3f9a4e59f7f9da812ca598c6869777637696d17b935b
# ✅ Saved block with hash 'd95cda9eb892b6efecb1b8b14537145fb57ad8032e4376bb2a5c3befcca2148b' to MongoDB.
# ✅ Added image '1 (1014).jpg' to blockchain.
# 🔍 Hash for '1 (1015).jpg': cbf8408e96aa88ebae3f48e2957597b24d89138b6c07e888b9b2884d1f13d6ce
# ✅ Saved block with hash '452f04c7445611baa9a293a1691b2c7e86d85ea7d96a6d4890ab2500f88d9eab' to MongoDB.
# ✅ Added image '1 (1015).jpg' to blockchain.
# 🔍 Hash for '1 (1016).jpg': f90c2ae2c05e0bd7427197b436b1ac0ce23cb7ecefbf6b77d89c52bd1c713dc2
# ✅ Saved block with hash 'fd49b54c564826592282f5384291b14b17928b16a55216b0963adcbcc5dd442d' to MongoDB.
# ✅ Added image '1 (1016).jpg' to blockchain.
# 🔍 Hash for '1 (1017).jpg': a1a7b6c33b567563286356fb4357f57008bebbc6457624d614cb7750e1ac6d1a
# ✅ Saved block with hash 'a48c47d16807c4dd1b24377e65e656e3f78c9ccc775917307f5d107188895437' to MongoDB.
# ✅ Added image '1 (1017).jpg' to blockchain.
# 🔍 Hash for '1 (1018).jpg': 17c9abe7b6a394344780cea5627723599237b6b5f6939be4a01a93e6d71a234a
# ✅ Saved block with hash '60e9475f25c74f756b8b988ba624fd4b6e1371e26a119f39bc1b1a46514549e7' to MongoDB.
# ✅ Added image '1 (1018).jpg' to blockchain.
# 🔍 Hash for '1 (1019).jpg': bc645fc421ecf0a756f8f14fed27a3b938a70804577d76b5604eb0986f24ccbd
# ✅ Saved block with hash '2de47ed9d738aa2217bf2fce27bd7aaa69e61ccd32af3b8a176f04378206286d' to MongoDB.
# ✅ Added image '1 (1019).jpg' to blockchain.
# 🔍 Hash for '1 (102).jpg': 8f1b2bba95b2917e22785bfc455abd74831864b23387a143828f6493999416e1
# ✅ Saved block with hash 'e43c7dd219c87d8575559b3912f3da16021badd50c9a92c03c5e78ba6b21927c' to MongoDB.
# ✅ Added image '1 (102).jpg' to blockchain.
# 🔍 Hash for '1 (102).png': a516ff55b4cc112b0f955c88b8af866d377b45bc3636247fa1a8c5c55a112304
# ✅ Saved block with hash '9613c5c72bb302fcc9ed5205bea8b732657f1b278f58c3092eb49f8a1dc03bd6' to MongoDB.
# ✅ Added image '1 (102).png' to blockchain.
# 🔍 Hash for '1 (1020).jpg': e2e466a6531a5a46f898fff28fd0ffa1832f64e06e437328bc21070b8bfac6d1
# ✅ Saved block with hash 'a39261f5fc9a2df9deeaa004f27cd5ffa9f67e95d8c62073f802788413959343' to MongoDB.
# ✅ Added image '1 (1020).jpg' to blockchain.
# 🔍 Hash for '1 (1021).jpg': 2d26c89e2049e3d9d21915fabe7a224689be67f82cb3357eeb9a87ec81a004fb
# ✅ Saved block with hash '263b0cc15d04d4b20062ba61befd3031c63d7123540adf324e53d688e866ab1f' to MongoDB.
# ✅ Added image '1 (1021).jpg' to blockchain.
# 🔍 Hash for '1 (1022).jpg': 72f26daf01a8125ee9232cfeaae427960d8eae9121839de4df9a744fb2da2d11
# ✅ Saved block with hash '23be909a4778be681d317cd0cd48e4c2f8a099d6e9630d29329a9e9bd13a14ba' to MongoDB.
# ✅ Added image '1 (1022).jpg' to blockchain.
# 🔍 Hash for '1 (1023).jpg': 271dc9d492fbb32fa10247a0e123feaf7a00c9142ff84db0c91093af0f3de4b7
# ✅ Saved block with hash 'a1b7c63781bf1123104935f7b7d3d390589f7e4b7ed5c1848ba0eee289557cb0' to MongoDB.
# ✅ Added image '1 (1023).jpg' to blockchain.
# 🔍 Hash for '1 (1024).jpg': 6a5b3e40d0899a12bebcf6424c61f2891e231b3ac1906bfaec8eb831a6074aa2
# ✅ Saved block with hash 'd70654b307ebefa6dcce8d6d9d9b9085fea4dfc629a8c4f8546573086b4d15b2' to MongoDB.
# ✅ Added image '1 (1024).jpg' to blockchain.
# 🔍 Hash for '1 (1025).jpg': dd7d23f972968d28b9e71377ffef08e7607ad61188ab5fc8f6ea2bf5f6cf05bb
# ✅ Saved block with hash '8e2160e2b9dcb0f2f625d2d01dcf881ad1e687edcc0c5ae3123fd0773cadce2e' to MongoDB.
# ✅ Added image '1 (1025).jpg' to blockchain.
# 🔍 Hash for '1 (1026).jpg': 6a5b3e40d0899a12bebcf6424c61f2891e231b3ac1906bfaec8eb831a6074aa2
# ✅ Saved block with hash '391f7f0f85a2e69d90e99d92a8934766ab15589a8023824474eb30b32271c3b8' to MongoDB.
# ✅ Added image '1 (1026).jpg' to blockchain.
# 🔍 Hash for '1 (1027).jpg': f17abb26f46747950d0c6173c276126dd8db42bad64ae35b44fa6b34a4625ec7
# ✅ Saved block with hash '15b9b26b8198fb88b159f63aa29db652c01125ec8a0e7fe0b16c9eae26ee87c2' to MongoDB.
# ✅ Added image '1 (1027).jpg' to blockchain.
# 🔍 Hash for '1 (1028).jpg': 88f9e548574f58bb230bc514ebaa01a54132b242648ebf7a6af5bd58ed339459
# ✅ Saved block with hash '4ec4cb5fbb7161fe631ac47e454b7c1ed68f42ce580a00b8d09634c664fbeaad' to MongoDB.
# ✅ Added image '1 (1028).jpg' to blockchain.
# 🔍 Hash for '1 (1029).jpg': 0e1c1bafc2cdef406d6a902ec05ab3242fe5f8002732d67227dc76e8c9f92641
# ✅ Saved block with hash '7b0a80aac6aed9863e3bbeea3e88e472b072a6a50fd5f1213448d69f99a6a238' to MongoDB.
# ✅ Added image '1 (1029).jpg' to blockchain.
# 🔍 Hash for '1 (103).jpg': 88002f7efcc38498814452452677757896679e9e03542dbd9cf486c1ba4b4cbc
# ✅ Saved block with hash 'e977ee03d79c4394b76b829c9e53447c080c2c7a81b4cebfefc0a3501c8b9c5d' to MongoDB.
# ✅ Added image '1 (103).jpg' to blockchain.
# 🔍 Hash for '1 (103).png': e5d608156e75351838ea3c545ec1cc367bf26c8c9e6889be53436d9e055c7e24
# ✅ Saved block with hash '1440a5040d8bca72d4dc104192266458ac2ea0cb8e716eefcde3f861ab0ddf22' to MongoDB.
# ✅ Added image '1 (103).png' to blockchain.
# 🔍 Hash for '1 (1030).jpg': 8faa479b831c25508b1564a9718f279cca5d8ddb9f1c0f1c35f56cd6cff6a559
# ✅ Saved block with hash '35504d562217e7471a47e88c40c06652017436e6162c26b42bd70fea4851c0da' to MongoDB.
# ✅ Added image '1 (1030).jpg' to blockchain.
# 🔍 Hash for '1 (1031).jpg': 29a6132d692c030491ca49685fe45580e0cecb515b131de1a56980a634e21479
# ✅ Saved block with hash '216a8031b6cb7bf96a6acda2a642bdd7a092982e21f712d87ae3b43470b5f041' to MongoDB.
# ✅ Added image '1 (1031).jpg' to blockchain.
# 🔍 Hash for '1 (1032).jpg': 8807bc7671498b616bf723c9ea17f0ca17a3da25617499cc502ecca49bc2d39c
# ✅ Saved block with hash '68c6d2a266359aa2a5a3b9e20186900e8ad40c5fcfeacb5a03284b9b37a821e9' to MongoDB.
# ✅ Added image '1 (1032).jpg' to blockchain.
# 🔍 Hash for '1 (1033).jpg': 964c179e4ed505abc4a749ce3662588c1b3ccebc51d1f6deb9b5b5a25da307f0
# ✅ Saved block with hash 'a195b71161dd45fb754bf8f95d33b674b72999af8bf20f4b86181e14cd8fdb9e' to MongoDB.
# ✅ Added image '1 (1033).jpg' to blockchain.
# 🔍 Hash for '1 (1034).jpg': 821b49df4e4211fdbed7bea3ba5276ae4b5f01ea81f9dfd0c6275761f380f75a
# ✅ Saved block with hash 'fb285edc145547560136a0ed7e93d98aa919735e836f75b706d279d158c1bbae' to MongoDB.
# ✅ Added image '1 (1034).jpg' to blockchain.
# 🔍 Hash for '1 (1035).jpg': f92b2d48ee96d65c191abad0b5fdf440d885532a3636916674d11a199fd7bb6d
# ✅ Saved block with hash '5eb85e08d9ee3e9e71ffe33ed3afcfecea15707fd13a4ed4993768ae40b42931' to MongoDB.
# ✅ Added image '1 (1035).jpg' to blockchain.
# 🔍 Hash for '1 (1036).jpg': 8aaacaafe5fbf3fb1c6c4d317d3123d65ce0e70ebe45da5973a35a4103490324
# ✅ Saved block with hash '783fd581acb03274b7bb3ce1332534d015c2b958488359d9258896d0626896ce' to MongoDB.
# ✅ Added image '1 (1036).jpg' to blockchain.
# 🔍 Hash for '1 (1037).jpg': 8588b218577b0022b1a1fabe4cd9dd04c7951b2de668337355ba6a61538cd9cc
# ✅ Saved block with hash '888e1fc4d67c0167db3a27ee6a8e566defd5990a8c87527584170b588d913024' to MongoDB.
# ✅ Added image '1 (1037).jpg' to blockchain.
# 🔍 Hash for '1 (1038).jpg': 7c7a5924d34d18942c5e82a844a3fb43a64e3a71368bd8413bfa2a76640d7bca
# ✅ Saved block with hash 'd4f9cb19b15f56f5c03f4b95ff310703dcd8f47e2cd1660beea1067fbe1a3373' to MongoDB.
# ✅ Added image '1 (1038).jpg' to blockchain.
# 🔍 Hash for '1 (1039).jpg': 7514e88f1d4b38707108fe07a0a9cfd702ec3f402172a5c5991a64d9259a533a
# ✅ Saved block with hash '46e6e5c33787e1bdd184d7f12845bc72338445aac6c4ffa4ec60a3039ab0ef04' to MongoDB.
# ✅ Added image '1 (1039).jpg' to blockchain.
# 🔍 Hash for '1 (104).jpg': b2eb8f470b4741c96b153a85b31afe6316bf265ed801baa82fc76ebea4844ab5
# ✅ Saved block with hash '28f421abd1c970b9b1f2af5e24d1fe82158da266c5bdc2d657d70838ba1828cf' to MongoDB.
# ✅ Added image '1 (104).jpg' to blockchain.
# 🔍 Hash for '1 (104).png': 6c832d277016b042e2a8b052f659ee64215ffe0a8cca108570cbc7bf27792d2e
# ✅ Saved block with hash 'f507eafe6e70007ab8f7c46404f99b74ca1016a70e91d800407673d92b2a4e6b' to MongoDB.
# ✅ Added image '1 (104).png' to blockchain.
# 🔍 Hash for '1 (1040).jpg': 97a4e52f6e71b626d82ee54d31b11e838981909e4eea39a055c768e653468765
# ✅ Saved block with hash 'ee0f738a39adf26d26470f335f454c56d79bc9ea9a22f41fe49b8babc80fc404' to MongoDB.
# ✅ Added image '1 (1040).jpg' to blockchain.
# 🔍 Hash for '1 (1041).jpg': 9ec47741e928c7c58cdbfc529fd785ccbf3932e60e64aee0af986ea03a5e431a
# ✅ Saved block with hash '9925ed045192a947c9107aba4251cdcc9e0ba379dce6327044dcec07de59f513' to MongoDB.
# ✅ Added image '1 (1041).jpg' to blockchain.
# 🔍 Hash for '1 (1042).jpg': 6e35e8a57c64397aed99a241c74ab06a9340ac753fe15e423e023c84182e8744
# ✅ Saved block with hash 'ad93e7b877069ade087fc15515568197e53646b51985ced008537f3be7654723' to MongoDB.
# ✅ Added image '1 (1042).jpg' to blockchain.
# 🔍 Hash for '1 (1043).jpg': b2b92fe853d2120503f91dbf40d0510759cfee6a256c29b34b9d25f6997b0a7f
# ✅ Saved block with hash 'cb1e1405c6d32fd2f155ae768f3ce6af056ee453e2407e3b7ebeb556a20c7c71' to MongoDB.
# ✅ Added image '1 (1043).jpg' to blockchain.
# 🔍 Hash for '1 (1044).jpg': 6ce0f0475e207310878ddc18a53dca5a223a935d99239549ff749cbf0c1c0043
# ✅ Saved block with hash '22f384095d5281a78534d923b4f810805709a2876f4b811b0ca729443fdef38c' to MongoDB.
# ✅ Added image '1 (1044).jpg' to blockchain.
# 🔍 Hash for '1 (1045).jpg': e89effb12ec21118460135d462d2db211c995dfc2b0720055fd001c4b2fde820
# ✅ Saved block with hash '2c2d7299038767db7a52d36da570496b3da42952f1716079f4d561fd9b7c2f83' to MongoDB.
# ✅ Added image '1 (1045).jpg' to blockchain.
# 🔍 Hash for '1 (1046).jpg': 91b6f4e833007f8b4b28053fd98f74c4b68ad7880cc51c6e35c95ca562ddeccd
# ✅ Saved block with hash 'b1a4f986c9060118e77feca665c3b0cefd825eee9ce2ae410a94185ac4342f1e' to MongoDB.
# ✅ Added image '1 (1046).jpg' to blockchain.
# 🔍 Hash for '1 (1047).jpg': 62f8bed49e1e74fde7c3692e224dbe6dab446e19e4e901cf8ceba4929bc1ea06
# ✅ Saved block with hash '0a47d946573acfd0eb8adaa8bf6f9da1048c9cd97160ec6e73b9cd74e8e57d94' to MongoDB.
# ✅ Added image '1 (1047).jpg' to blockchain.
# 🔍 Hash for '1 (1048).jpg': 022c41ab2a77276935a0bf85e82a7259012035c3f8c1fb272cc4db3a78441c76
# ✅ Saved block with hash '5f579a23fa679b5de37c9e010f5320b021aa5742d64d8b1877d3782e57ff15a5' to MongoDB.
# ✅ Added image '1 (1048).jpg' to blockchain.
# 🔍 Hash for '1 (1049).jpg': 7f6c633245625a81a4d3d542bd74f6bec0a2db9e1f90e8e6906fd6e2b1730f03
# ✅ Saved block with hash 'a56daff5a4d3d16156247716a9794aa51584434fbb39832382d0a61266ba1664' to MongoDB.
# ✅ Added image '1 (1049).jpg' to blockchain.
# 🔍 Hash for '1 (105).jpg': e898bb261004b9d4b52438bd61ad6be90b7e980fa41ca39b99845e1c3cca74d0
# ✅ Saved block with hash '41d0482b47040020c1a5eab6b9294f41f76d46272048f652143f260305b0ee5f' to MongoDB.
# ✅ Added image '1 (105).jpg' to blockchain.
# 🔍 Hash for '1 (105).png': 38cbd23a308a0ffad28534e9cb3ddee020061407842d951e91edfa2d1059c3fe
# ✅ Saved block with hash 'e2494d26f4dbef82aa3dbb8852bc65b27d169535963b228e299c9e8a089b401e' to MongoDB.
# ✅ Added image '1 (105).png' to blockchain.
# 🔍 Hash for '1 (1050).jpg': a872a50d85cf0d266078759f8a45fcf41f290fb36760faa283954f0dd0cf5ea7
# ✅ Saved block with hash '2543529c71ea4d822e22b67840813a7c60a5000a18e63ee3a6430cfae6fc8969' to MongoDB.
# ✅ Added image '1 (1050).jpg' to blockchain.
# 🔍 Hash for '1 (1051).jpg': 2d3c340a9c8e0e76394fe6819adce570d4fbb37c46c3ab9b8ecc4cb7b4069341
# ✅ Saved block with hash '411f11d2d3cee75d32e0b78247d77cfd80e4e2348b14d0ae27f07d924e1765a3' to MongoDB.
# ✅ Added image '1 (1051).jpg' to blockchain.
# 🔍 Hash for '1 (1052).jpg': 1bc88ff691120eb5f82515ea4d432b1df27ed0707fcc0a2368d7c05a8a5b66ed
# ✅ Saved block with hash '4d76349526c4c60f7ea8726d799e06eb0640fb5fae377dc7338933b56c8139ae' to MongoDB.
# ✅ Added image '1 (1052).jpg' to blockchain.
# 🔍 Hash for '1 (1053).jpg': 896cb9bf633927f67035daa4b763fc3b9b6e5bd6d4bfac5d46006c5ae221a1c7
# ✅ Saved block with hash '71d92645ba0ef33d2fab97ee61ba3120cd9f93072cf36a5071c855d058020cf2' to MongoDB.
# ✅ Added image '1 (1053).jpg' to blockchain.
# 🔍 Hash for '1 (1054).jpg': 23758287405478d070448c1eef62a391224ea2e9d671d8732b41639f55f11e4f
# ✅ Saved block with hash '8f11210f06849efce246d8acefe22fe609bfc942556614ebd4a730c6c21c7d63' to MongoDB.
# ✅ Added image '1 (1054).jpg' to blockchain.
# 🔍 Hash for '1 (1055).jpg': 8583133affdfe5d64d06d0430f6c48565eaa23c254d398c00c93863dc0a2fe13
# ✅ Saved block with hash '9c051fc65eb9a2ff3d1176a81652afaa989ed16dd6399ed5482642730486d6e4' to MongoDB.
# ✅ Added image '1 (1055).jpg' to blockchain.
# 🔍 Hash for '1 (1056).jpg': 1cfbb0cab70917a7f85c0d3121f518840584975719f608a93bab6a6b1446c57d
# ✅ Saved block with hash '78903ced3c4a7fe59078dfd662469feaa6506ace636c85b058ec538d139d4c38' to MongoDB.
# ✅ Added image '1 (1056).jpg' to blockchain.
# 🔍 Hash for '1 (1057).jpg': c4bf00a93652d6115ffee918fc4794116654043b8bdbad45506e07dc42a241c7
# ✅ Saved block with hash '7039560c8627c61e579721f42cee1f720a4c1915a850e76ceba441961a731383' to MongoDB.
# ✅ Added image '1 (1057).jpg' to blockchain.
# 🔍 Hash for '1 (1058).jpg': a0d24efd86cca67f868ed99ff93b6f4802e951c5e3a1c770d01a34dceb5d00df
# ✅ Saved block with hash '70080d147beb567f7e7eb4b6b518d41c09a32080ba67757afecc7477547d928b' to MongoDB.
# ✅ Added image '1 (1058).jpg' to blockchain.
# 🔍 Hash for '1 (1059).jpg': 56de5996d9ddc33889a441cb304f57d8ce694e2eae6056cb07f651121aef9915
# ✅ Saved block with hash 'bc59de671b57c4a7d4e0f2e89c291f6562b27d5538008823114a87bfcde05a25' to MongoDB.
# ✅ Added image '1 (1059).jpg' to blockchain.
# 🔍 Hash for '1 (106).jpg': 024146dbd817a4679f94cac7420b1f94a5d7075d6dc6dce00b93be212c62a9be
# ✅ Saved block with hash '4510fefe968449097e145ad6c93c23ade39005b280ba47fd902ecc4f4fb154c3' to MongoDB.
# ✅ Added image '1 (106).jpg' to blockchain.
# 🔍 Hash for '1 (106).png': 5acc9207052eb427527d038bad7d585e1633164ec6c39c28b979b1cc3bd98dfe
# ✅ Saved block with hash '2113daf00cef9b38982493ed55413e1590973211acc43152f119c86edae9d4d5' to MongoDB.
# ✅ Added image '1 (106).png' to blockchain.
# 🔍 Hash for '1 (1060).jpg': dbc1711edcea86e2bbd41b011098160fe280cf2223ad4968822a5ae0a7476d45
# ✅ Saved block with hash '9af4802966f256316b8aadb439fcb3b65a55ae34a74efa1eafbe1ca9c5361ea5' to MongoDB.
# ✅ Added image '1 (1060).jpg' to blockchain.
# 🔍 Hash for '1 (1061).jpg': 1fbf6bd07ec9e915cd91686ffc740fefdba8a2696b38418e4f0abb01243d0829
# ✅ Saved block with hash '5b6c86c275392b8bfbb87e58508ffccf41a67c2b76667c38436b7b7715ab9944' to MongoDB.
# ✅ Added image '1 (1061).jpg' to blockchain.
# 🔍 Hash for '1 (1062).jpg': f33543a94353a0898a94bf2d53128fba5b968af4cfd58acdff55449d98acfbe8
# ✅ Saved block with hash 'b504ee296edca1ec854c6bca7bf0086cc041e928deda7a88ea4639f3e41f928a' to MongoDB.
# ✅ Added image '1 (1062).jpg' to blockchain.
# 🔍 Hash for '1 (1063).jpg': cb62dc2a0312ade38a744f1773e9ea701c8f31ef029a7a6edf2b94f85180dd0a
# ✅ Saved block with hash 'bfee6b12ae76e3335f4e19075ae44c265ddc3c51516f04c6167053d34c7f9a52' to MongoDB.
# ✅ Added image '1 (1063).jpg' to blockchain.
# 🔍 Hash for '1 (1064).jpg': eaf9d8518c7a77a18e1e7dbe346cfb55976e05ad58164adff249fb806c9d3e0a
# ✅ Saved block with hash 'eb1e70dbc14762c23a4a8b1a7af135365828c1915ca614bb9d302a898af14eb2' to MongoDB.
# ✅ Added image '1 (1064).jpg' to blockchain.
# 🔍 Hash for '1 (1065).jpg': 8aaacaafe5fbf3fb1c6c4d317d3123d65ce0e70ebe45da5973a35a4103490324
# ✅ Saved block with hash '675536e4fab51c6814fc9c7195cf4ca5720fb224e28ce61986107dba9cd51c98' to MongoDB.
# ✅ Added image '1 (1065).jpg' to blockchain.
# 🔍 Hash for '1 (1066).jpg': b3d5abc4a91cb1d0db540b38da1d83033181218a3c15214846684deb83b0d174
# ✅ Saved block with hash '616ed213f437826d1eb13f4f7717cfb6e7735ce3460a31a08eaee4a79ef96765' to MongoDB.
# ✅ Added image '1 (1066).jpg' to blockchain.
# 🔍 Hash for '1 (1067).jpg': afbb46d903905b3aaf85fc53f74da0756c14a4abea0798a1f109a91409834a49
# ✅ Saved block with hash 'c4b3117af50f05b6d843f1f82afe29eeeaf77a253a8531a61e8bfaf4ca3eb3c2' to MongoDB.
# ✅ Added image '1 (1067).jpg' to blockchain.
# 🔍 Hash for '1 (1068).jpg': 1b54904cb38f309cc6a2d4bb29bfd95e1448022cc188f8aa6f5367438d2ab976
# ✅ Saved block with hash 'af3fd9b45facd543321f32f6b5b291da01bf9e7620c5e62372e071a471facfc5' to MongoDB.
# ✅ Added image '1 (1068).jpg' to blockchain.
# 🔍 Hash for '1 (1069).jpg': 48cca1d9b08e286c046adb7c97296e183dfadbf65552480f2b3e147072293211
# ✅ Saved block with hash '5b704f3a533fefff1a0276f2731e3eea70f79ea13f2055199d084495a804e538' to MongoDB.
# ✅ Added image '1 (1069).jpg' to blockchain.
# 🔍 Hash for '1 (107).jpg': b578fec309c53a4953a8f4b5b212cbe87eed25b117776b759726ae5beee1fc7b
# ✅ Saved block with hash 'b567d433aca9ddfc1ad8a23db98224f6a16b0e2a99ee0b0ec5350160401b9d54' to MongoDB.
# ✅ Added image '1 (107).jpg' to blockchain.
# 🔍 Hash for '1 (107).png': 1294a57b1f26f69c4b357d13e2a4fbaa23e9404a403bdb525fad10b5fc3bbaec
# ✅ Saved block with hash '8290c94ec1cfe35d64a86bd395564ba037fd4b6bedbe8fe4ce9ba28aab4efa2b' to MongoDB.
# ✅ Added image '1 (107).png' to blockchain.
# 🔍 Hash for '1 (1070).jpg': 22e3bc7b7e64d4f3bf6ac22bce5c2673c103eb6a28d63a601cae6a49627e6502
# ✅ Saved block with hash 'db2a9e346568ac9e91d19e7771c30abf8378e95ccb89ff007dd6cf4d384a1e31' to MongoDB.
# ✅ Added image '1 (1070).jpg' to blockchain.
# 🔍 Hash for '1 (1071).jpg': 3e95dfd7ebc13ab914be582ce28abc869e4256077feafa390ad1eb819ebf5633
# ✅ Saved block with hash '3b1e812cb60adf9757a2b9d6665c091bf48b26d6e3484cc7b9597f1ac2d5ee55' to MongoDB.
# ✅ Added image '1 (1071).jpg' to blockchain.
# 🔍 Hash for '1 (1072).jpg': e64b555222a4b21fd99aa5c78d913d220b96417dbb027cf6734ac29dfda08e91
# ✅ Saved block with hash '1fb3764c2994d03ee8d42fbfd09b523d0c31888c0b0dca4e7043ccf794c2edf4' to MongoDB.
# ✅ Added image '1 (1072).jpg' to blockchain.
# 🔍 Hash for '1 (1073).jpg': 5d9dca51d4bbd62157f730a3626fadf65b8b9b8bc00b7b2875241490c86f16e9
# ✅ Saved block with hash 'e0fa388a8e2eaf41461a6171f963d9cbe85514e8340753434d1fb9d7546c31ed' to MongoDB.
# ✅ Added image '1 (1073).jpg' to blockchain.
# 🔍 Hash for '1 (1074).jpg': 0ab9100c443a3d1c6a2ce5a7f5780ca708ce1600fa81a38f6ae01cbbf1250ad1
# ✅ Saved block with hash 'f7cf574a8ad8308ac19892aaf5886c002f8c050e55581e79946d1af45d209a5a' to MongoDB.
# ✅ Added image '1 (1074).jpg' to blockchain.
# 🔍 Hash for '1 (1075).jpg': 08b5f67d1fc776db5e3b85121e92823bf34f33512e9f03c704ed2670bc314fc6
# ✅ Saved block with hash 'd0dbeb777e1bc5e037e13fc72aea70d0ee36e5b253433bbfc3c1e9441afad0a1' to MongoDB.
# ✅ Added image '1 (1075).jpg' to blockchain.
# 🔍 Hash for '1 (1076).jpg': cc536255adc67294a44283fb8c0e370776b6bc2fe6a89c1c0cf22f4ba36577be
# ✅ Saved block with hash 'f766794b28ff878e7500e52d7b4eb1323a965ec7ffa1844414bbb7d6263c77a5' to MongoDB.
# ✅ Added image '1 (1076).jpg' to blockchain.
# 🔍 Hash for '1 (1077).jpg': 203348d88b99d3f3b0ceae1aa24fe93dc48949aec1a0a9bfa2e336218a9c7436
# ✅ Saved block with hash '0e08e796ea8d380f3b8d3d2a3c42100d461871fbb39abce6116caa0e82375e9a' to MongoDB.
# ✅ Added image '1 (1077).jpg' to blockchain.
# 🔍 Hash for '1 (1078).jpg': 2ab4018e6240de777247ac21250caaf777a2248570fc63ab7de5c00f8cd3d1dc
# ✅ Saved block with hash 'b2e72839d24075eb6b644461ad61d865a3e843ef21458faa5dae519edd7a0b4a' to MongoDB.
# ✅ Added image '1 (1078).jpg' to blockchain.
# 🔍 Hash for '1 (1079).jpg': 53650d071cd2a688d72f8662117b6ddcb67f6ef2c7175348b5fcd7d9ff8122c9
# ✅ Saved block with hash '3efbf0a6891611f3191579a904ce210cb53bbf4ef014aa5fac8647af682f64f6' to MongoDB.
# ✅ Added image '1 (1079).jpg' to blockchain.
# 🔍 Hash for '1 (108).jpg': bf879b5f55bbf4d121177c1b9c1731638d645b6e1eb9adcf4d550bb160b72aa0
# ✅ Saved block with hash '5ecc5f3aad4ee20a42592104e372834aa4a627c0a6bcfc26a5d1577535b79e74' to MongoDB.
# ✅ Added image '1 (108).jpg' to blockchain.
# 🔍 Hash for '1 (108).png': 30b6877ff2f036414aa91d72ba3fd8ae04421a3e64296093176c7f32778659cc
# ✅ Saved block with hash '9a8c9605562b3691026a3f25941e80141ed415dfa46376810707f723d267b8bf' to MongoDB.
# ✅ Added image '1 (108).png' to blockchain.
# 🔍 Hash for '1 (1080).jpg': 8e71866c3bd4341b9dbf438469bd51ca48c1b7da625877887b9d1787dd883c7b
# ✅ Saved block with hash '93167d037ea812ee6791c899e7f02671f53ceb0fb8b2fb1cef651f66801f2547' to MongoDB.
# ✅ Added image '1 (1080).jpg' to blockchain.
# 🔍 Hash for '1 (1081).jpg': 88f53872bf7b113c511c4df570b5baff6cb01231c2d7eab7ba7f92f5080e1a69
# ✅ Saved block with hash '8d517d5fc900a0f733f1528916e5f122b7fc5d3188b5eb270d79a1874941a975' to MongoDB.
# ✅ Added image '1 (1081).jpg' to blockchain.
# 🔍 Hash for '1 (1082).jpg': 853708cd49ecabac355bcad9854f44ad19c6824d285f8960f89cd3a9813d05c7
# ✅ Saved block with hash 'edeadee0658e1cd2d6b4a1a583df8ad5b1a9c1ac9baa1295c4bcea0fa1506838' to MongoDB.
# ✅ Added image '1 (1082).jpg' to blockchain.
# 🔍 Hash for '1 (1083).jpg': d83ca49e65acbcd3d8f4b24dc92ac890602a296034292368c6bd3b4b0df27f8d
# ✅ Saved block with hash '7cb14c4405d89de01b1c55c865eadcebd478c877761c05fecaac2c5184a93027' to MongoDB.
# ✅ Added image '1 (1083).jpg' to blockchain.
# 🔍 Hash for '1 (1084).jpg': fe97a146c05cf2a0113140722b0471d5fddc80ca3049a592530256530228f3bb
# ✅ Saved block with hash 'b3e28ff731ec96d03dd7feb2ade68533667cba9d2760857533c2d8d5e1bc7003' to MongoDB.
# ✅ Added image '1 (1084).jpg' to blockchain.
# 🔍 Hash for '1 (1085).jpg': 5020756ff7dc1eac137a6360732ee0e6b886c12e6ce4b514c8c531723103812a
# ✅ Saved block with hash '7fb0b46bae9d57cdd4d226a2971d765da568493760974145cba528d031c6a442' to MongoDB.
# ✅ Added image '1 (1085).jpg' to blockchain.
# 🔍 Hash for '1 (1086).jpg': c007ba2c692479ff533a9e144a12858536076772c37d87f96ebf0bf539f4c1ef
# ✅ Saved block with hash '718969b696c4878c09d5c59a085cba9fec61f54f93a0b260dbe661d87c96c1e3' to MongoDB.
# ✅ Added image '1 (1086).jpg' to blockchain.
# 🔍 Hash for '1 (1087).jpg': d097b9f1ed398c9a2c938602f3bf81503d36f0f45c7a2463a02014b2a865f253
# ✅ Saved block with hash 'c642f32e9ca7eef24fcba1e5b995c2ff72bc80233dab63d18a949c515d98d1f1' to MongoDB.
# ✅ Added image '1 (1087).jpg' to blockchain.
# 🔍 Hash for '1 (1088).jpg': 12d183639ae70c5632a0990b448fcc9d8b3df0bcf38862e74b26673d176746d3
# ✅ Saved block with hash '2b2d85e0204fa82c62e474b78079d4dcf298f0ee854621d13227d50b3b7d2962' to MongoDB.
# ✅ Added image '1 (1088).jpg' to blockchain.
# 🔍 Hash for '1 (1089).jpg': 281527a8eee69c8ad09e42a10cf9a9a9df45c312aa493b3baacb8ce0b9e6609f
# ✅ Saved block with hash '9fa2f9b275f7631fc8cb98026f087f9b6c3fed9e9490fc452e08f8156a66ffe0' to MongoDB.
# ✅ Added image '1 (1089).jpg' to blockchain.
# 🔍 Hash for '1 (109).jpg': 3dcd9172cb397c593914bd9766470de73ece0a05ddf8f327c95783e8272a9008
# ✅ Saved block with hash '5ac3074ab039eaffbf3904898e90b0bf33040588d2ded1176992aaeafdf6a712' to MongoDB.
# ✅ Added image '1 (109).jpg' to blockchain.
# 🔍 Hash for '1 (109).png': a840a8ff6c4e3f4231a5fe17a73aa4e4f10d307b6a76e11e35371dbb13931b52
# ✅ Saved block with hash '7303dceb889212d486d5cebba3fdb951c45f54fa019b25188635d031819790f7' to MongoDB.
# ✅ Added image '1 (109).png' to blockchain.
# 🔍 Hash for '1 (1090).jpg': 4c53e288442fd62bdb466e9a39da36247b4eb480c89186fb5409a22b2bfa95f7
# ✅ Saved block with hash 'e3dcb4a6e240a201fbd4fc98f97168c6f9220beb380b45e225bacc36b463ad10' to MongoDB.
# ✅ Added image '1 (1090).jpg' to blockchain.
# 🔍 Hash for '1 (1091).jpg': cf3d89bc67f1a150a9a70ebbdad1d0bd7aac9ee82ece19917adb1a8a536927a5
# ✅ Saved block with hash 'e343f996b69fe51eac3dded8ba6274f5a864435bb15fc02740b3ab2f669f26be' to MongoDB.
# ✅ Added image '1 (1091).jpg' to blockchain.
# 🔍 Hash for '1 (1092).jpg': 0d5d93dd705b2ef1316cac55b7bc09255b70c34a4c201e3e78bea942738be304
# ✅ Saved block with hash '4ee6852ee2fbcb54aed84791baa586d18588cc1f7252c2ded59cd39175dbed05' to MongoDB.
# ✅ Added image '1 (1092).jpg' to blockchain.
# 🔍 Hash for '1 (1093).jpg': 60a4ee0b0a58fbc5ee187cc458ab534f0b52559ec58dc35a359ddf47fce5dae9
# ✅ Saved block with hash '52b9c9bae6fb0146258530754983dd68b34bd5d34f10fe4c373db04c55f5d090' to MongoDB.
# ✅ Added image '1 (1093).jpg' to blockchain.
# 🔍 Hash for '1 (1094).jpg': f1143c789d65cb4dc37bb3d59ebff1507154b5c6f3e57eaa9333a45a272a1408
# ✅ Saved block with hash '875c67c294c5288e02204314524c454b05dde1051e32fb76be946af929bf2c2e' to MongoDB.
# ✅ Added image '1 (1094).jpg' to blockchain.
# 🔍 Hash for '1 (1095).jpg': aff86696bc7d618d06573711562c9dee1f3e01525a15fb7545d6dc807cd01bf6
# ✅ Saved block with hash '2e1c4fc26162bd1b0671b8fcf32b4047d0e49ec8daba93b7ae26e44aa1e73560' to MongoDB.
# ✅ Added image '1 (1095).jpg' to blockchain.
# 🔍 Hash for '1 (1096).jpg': f0337de95a8d74c47f707fd880df23578c9e3ad173f52834c3b8d20f997c4f4d
# ✅ Saved block with hash 'a40098cb1e8d9b5d723f36b44f5048e76809a72b1ccb83d75a0a34ff6ba20519' to MongoDB.
# ✅ Added image '1 (1096).jpg' to blockchain.
# 🔍 Hash for '1 (1097).jpg': db450ac167514ce4a379498df60217453f4ec3870c166fc42245c43941327737
# ✅ Saved block with hash '8cf19e7f26b8b619c4fa2111fb831ab8814b3fec8e14421df85ccfc8e566518c' to MongoDB.
# ✅ Added image '1 (1097).jpg' to blockchain.
# 🔍 Hash for '1 (1098).jpg': 620dc6208ee5bcef044ca05f161d95de6a8c98cf3334362985975595d6b48059
# ✅ Saved block with hash '4fceba9da91215073746da2c930f582a2e12c6087988a484c0d9a8b4d2919a8a' to MongoDB.
# ✅ Added image '1 (1098).jpg' to blockchain.
# 🔍 Hash for '1 (1099).jpg': b96ab6b5b5659ed08d3b8979506b8bbde3cdad768dd1eab1b5b7bf8fddf3368f
# ✅ Saved block with hash 'c828f56585f538129980ab1ba1c00e867e77c23b5c2098e838508d7a97df9b70' to MongoDB.
# ✅ Added image '1 (1099).jpg' to blockchain.
# 🔍 Hash for '1 (11).jpeg': 87e0c2e3c89714551f317e65a0aee4a95ead517734b8c83b2d29a97dbf464b81
# ✅ Saved block with hash '8d6e7e3688dca4d2986e5573d47723cb8573d4a45e8c1dfd03089205529f9658' to MongoDB.
# ✅ Added image '1 (11).jpeg' to blockchain.
# 🔍 Hash for '1 (11).jpg': a07d195a748624fbd381f633137cf2579c3784795bf5ef7a48437f408733ae46
# ✅ Saved block with hash 'cf80e824dc81a8a656621c1c633d867ae891cf562c62f0aa4541c7f155a3ac61' to MongoDB.
# ✅ Added image '1 (11).jpg' to blockchain.
# 🔍 Hash for '1 (11).png': 1a238bf15a3dce701f2fcdaa68b5f27ad27c87302798a3c9871b4477728c230a
# ✅ Saved block with hash '50650c1a0dd2751a043fdb9103a6b409c6386ff9c80ec13aa717a808da19767b' to MongoDB.
# ✅ Added image '1 (11).png' to blockchain.
# 🔍 Hash for '1 (110).jpg': 4ab1cae1ed1cc7f9f38444f576beb32fdc064c1019290f3ec4028621149a1d22
# ✅ Saved block with hash '364941900d34efff8cfc2f1c6c663f65a869f7aa15c18d8038bad2460b9192d0' to MongoDB.
# ✅ Added image '1 (110).jpg' to blockchain.
# 🔍 Hash for '1 (110).png': 78889c5774c29dbc9c94fa8ddca2519ba83392db51e49f6661848d1ad082bba4
# ✅ Saved block with hash '070229a38ea4088e5b4c254d198aecdba010bcbeefe78116aa51bce6aa4b55fd' to MongoDB.
# ✅ Added image '1 (110).png' to blockchain.
# 🔍 Hash for '1 (1100).jpg': 663c89f36524ed2c3df7ccc12ec006cb139a4229f859116259eb6f06cef6bbcc
# ✅ Saved block with hash 'acfe3deff4a94bd1a273c17364072f46680e3ae60d1195995753fee8242c579e' to MongoDB.
# ✅ Added image '1 (1100).jpg' to blockchain.
# 🔍 Hash for '1 (1101).jpg': e895dcfdb1cfe69ca8b7793590ae177e8d34a75dfd7b8ba39ef132338a0c2f5f
# ✅ Saved block with hash '6d4b83eeedb0055ab72f3be8a3dac46092ec8494b34b3b154365cf3bf2db7170' to MongoDB.
# ✅ Added image '1 (1101).jpg' to blockchain.
# 🔍 Hash for '1 (1102).jpg': eca030a386d4260b3e9d9fb576a16ecc52c9d15605f22714dc06c3d1df1c82b2
# ✅ Saved block with hash '6af97e6bdfe3dfebdeeb0effc182eddf80f754d7e4515004574e6725b65d90ab' to MongoDB.
# ✅ Added image '1 (1102).jpg' to blockchain.
# 🔍 Hash for '1 (1103).jpg': 04741fbbe9a0874c69a9c9617060556add3a6736c8613f1b049cd658abb269b0
# ✅ Saved block with hash '8d310ecc5e4f42729e9a2cf57a4c91aa19f3a57a4b5f2381d86564b5e7f4c171' to MongoDB.
# ✅ Added image '1 (1103).jpg' to blockchain.
# 🔍 Hash for '1 (1104).jpg': 59ccc70058c475e713bed4b23855d8e20450fd7f07b25d5004d76d05f43b51e4
# ✅ Saved block with hash '5f1a3e8e077328ed8d89c15139318dccf4c4f61b256da91cef98d721d7efb0fa' to MongoDB.
# ✅ Added image '1 (1104).jpg' to blockchain.
# 🔍 Hash for '1 (1105).jpg': 617cd12d32a6a9a97b9fb8b84f4c4d29ccd7e0e2e58fa7ec8905fa99a9bd1c1e
# ✅ Saved block with hash '4da532a484e067dc184ee6c78ffc3c2fac9f4d80f798322d245ada7d41f420e1' to MongoDB.
# ✅ Added image '1 (1105).jpg' to blockchain.
# 🔍 Hash for '1 (1106).jpg': 3a3a1379267c68919bfe45d7140c66efaf4818f2d4f98e257acbab50e7df56aa
# ✅ Saved block with hash '6e53ebc3f7294a4f26b94109e97c6709a43e677146cbf48ef0735bc6abb2e2b1' to MongoDB.
# ✅ Added image '1 (1106).jpg' to blockchain.
# 🔍 Hash for '1 (1107).jpg': 3da7482f14a3104d6991bc885193ded46750b3c224d0f1526501e08dcdb86f54
# ✅ Saved block with hash 'd850a2b18dcc845734d7cc439f212c3326d52770be84ba44c257e887705222f5' to MongoDB.
# ✅ Added image '1 (1107).jpg' to blockchain.
# 🔍 Hash for '1 (1108).jpg': f3402edd21c554ada1701bca7b1ed1ea6128d0970af46e4768f5a496d8db0afe
# ✅ Saved block with hash '8a1c2049ed5ddf9ea8e822ceec03802c492a8958596b6ac10d07d09b4a50bb41' to MongoDB.
# ✅ Added image '1 (1108).jpg' to blockchain.
# 🔍 Hash for '1 (1109).jpg': 85d7d84d6da7e0b702719ddca1ecbf160d3f92e2ab42696dbbada9e56b65ebe4
# ✅ Saved block with hash '069b1bf1ed3f80e4a004ce57bd0d90ffc60c883df04aa5ed43985a9c7c0a4197' to MongoDB.
# ✅ Added image '1 (1109).jpg' to blockchain.
# 🔍 Hash for '1 (111).jpg': 72e8c43cdc8ad6a731e2a6b5c9e0addd00e5a4e76b34e9166343afd1418d1b2b
# ✅ Saved block with hash '68479e93b685775b2618205a821e4f5ec96c959556a3ee2a507a1e260d3ed1ef' to MongoDB.
# ✅ Added image '1 (111).jpg' to blockchain.
# 🔍 Hash for '1 (111).png': 1ada7e4941d0028565f50bc5f380a9f0fdf70daedd15b019eccb520118868e3f
# ✅ Saved block with hash '7b630db8b1289b55880fb798534888d4dfabbaf4e93a30bae2e3b03b6ac66315' to MongoDB.
# ✅ Added image '1 (111).png' to blockchain.
# 🔍 Hash for '1 (1110).jpg': 7d4a839aba431d6660e7e723b8b4e2e51edd23950c8d7d787b627551d351a66f
# ✅ Saved block with hash '9c482ed3d393d091463548f061446bb4fb1d7030da2f57c3db5855f66b30d023' to MongoDB.
# ✅ Added image '1 (1110).jpg' to blockchain.
# 🔍 Hash for '1 (1111).jpg': 96a41c8c812e59f5fb807b38f8e2d05ed0fd2b5f8afa5a5444c368b77bed6417
# ✅ Saved block with hash 'db20254e07aceb155995dbd374b80bc05ff9b378fa6443ea8bee8257f94752b3' to MongoDB.
# ✅ Added image '1 (1111).jpg' to blockchain.
# 🔍 Hash for '1 (1112).jpg': adbe506f7ab5a1228c67c5fe3b6920b672c5155919e83553106a0de7d6e82d6b
# ✅ Saved block with hash 'bbcbab483d74100f7d3c28995061f1ee9c13be5f34d130a06b2edd46c8d23430' to MongoDB.
# ✅ Added image '1 (1112).jpg' to blockchain.
# 🔍 Hash for '1 (1113).jpg': b4fa82822f34773f3c829452cc8245b2c0764f595a05a4929a02c1ea0b302f5d
# ✅ Saved block with hash '289fb9411a49f87766da769c623f43a6cd3fc05b4a3db5b960704611e3cd00bb' to MongoDB.
# ✅ Added image '1 (1113).jpg' to blockchain.
# 🔍 Hash for '1 (1114).jpg': 28de625a82ccf654fbe4d09e788e9cf1ff52379e02e44ab445d2d96af2f34c70
# ✅ Saved block with hash '3b0ffbfd42687c319fafafda6661df150c5aedf094f0a02b0eedb5e8b3d89fd0' to MongoDB.
# ✅ Added image '1 (1114).jpg' to blockchain.
# 🔍 Hash for '1 (1115).jpg': 4706f10925a89b7ea2881be291e5043323a3fd39886656f925566b19083cccf0
# ✅ Saved block with hash 'ab4f118c77bcf8d7b95a67fa67b207005204ab9e83fa203d7fb5a41112fe9237' to MongoDB.
# ✅ Added image '1 (1115).jpg' to blockchain.
# 🔍 Hash for '1 (1116).jpg': 443dfeb9c6359890481c6573ce1eac41efc587d88f987824214d43c0243ae20a
# ✅ Saved block with hash 'da86df5e15417eea0f49c18090da1f23724e67efd5440ef17bd54ec6806adc09' to MongoDB.
# ✅ Added image '1 (1116).jpg' to blockchain.
# 🔍 Hash for '1 (1117).jpg': aa57fcd4599b43c21e4fd23c20b255663ff0fb534f371135b2af81ddf340eb14
# ✅ Saved block with hash '582bbe88c1434ab40033484f39cc4e04a19681fa6319770ea4cf757d0a9465a0' to MongoDB.
# ✅ Added image '1 (1117).jpg' to blockchain.
# 🔍 Hash for '1 (1118).jpg': 8da5dbe7311d3aef2d232dce470104c3c87ad65349c4e108dd3ea13f93629b66
# ✅ Saved block with hash '89802659720a5beaa1d62a6386fa8a4b9d2b44fd98a9ea95b10832e35a8f2930' to MongoDB.
# ✅ Added image '1 (1118).jpg' to blockchain.
# 🔍 Hash for '1 (1119).jpg': f347579433fde00093680160c89056ce5b0c4d7354cd7d2a848b5baecd778791
# ✅ Saved block with hash '561a3725ead400a5ef252045b36fb9ee5704273ce4b6127525584123793e10c6' to MongoDB.
# ✅ Added image '1 (1119).jpg' to blockchain.
# 🔍 Hash for '1 (112).jpg': bd4c376e8093b084ce5071f70d9d09b296557c496e2b588a2a28be6ee7919832
# ✅ Saved block with hash '673fcbd58e8fc18411adb4d6fd6d2b936b34af762d390f663250347dc956a665' to MongoDB.
# ✅ Added image '1 (112).jpg' to blockchain.
# 🔍 Hash for '1 (112).png': a516ff55b4cc112b0f955c88b8af866d377b45bc3636247fa1a8c5c55a112304
# ✅ Saved block with hash 'f11248c7f61311d00ff8d820e7f23d4088f25406dae9a7a7a0b6104636173b94' to MongoDB.
# ✅ Added image '1 (112).png' to blockchain.
# 🔍 Hash for '1 (1120).jpg': 4788d8df4f1186df650b506888926bd135864b2e91351fc729dcbb5ae52cff78
# ✅ Saved block with hash '157e3303525e47e2dd348c628365d590deb8272d896a361c9a2438480fa66976' to MongoDB.
# ✅ Added image '1 (1120).jpg' to blockchain.
# 🔍 Hash for '1 (1121).jpg': 663c89f36524ed2c3df7ccc12ec006cb139a4229f859116259eb6f06cef6bbcc
# ✅ Saved block with hash '43a72afb7b0b21742e71741964e6758577d9bcb71e15a2e74ab0deedd5a9b058' to MongoDB.
# ✅ Added image '1 (1121).jpg' to blockchain.
# 🔍 Hash for '1 (1122).jpg': db76483cc417ea50cf0e8d59061bb30b8a1aefacaf9b025c2ee394477cc718f4
# ✅ Saved block with hash 'a9daac2457f7727ccced2fe5c9cb1c373ebb654d3c2be70feb49673f3368e638' to MongoDB.
# ✅ Added image '1 (1122).jpg' to blockchain.
# 🔍 Hash for '1 (1123).jpg': 46e5c274c6b2107b2b9b415e6b03bd2dc55a3c8bcf1ea81298c5084bd00b3980
# ✅ Saved block with hash '8210a58f46599d46bfdd57af95c01f90ac7b1a77f078724070add5b10090cf21' to MongoDB.
# ✅ Added image '1 (1123).jpg' to blockchain.
# 🔍 Hash for '1 (1124).jpg': 02fd02cd7fe34f4bc2dad5b971336b988289791ff0e071b622b7850b1e005000
# ✅ Saved block with hash '78c15e27f207eba80a696b2421168e571a8e6fb9f2fe4992d7c82d241d6f4e68' to MongoDB.
# ✅ Added image '1 (1124).jpg' to blockchain.
# 🔍 Hash for '1 (1125).jpg': 923f324b9ef15b4527df40ff46f2e2ee9800c852d225a66bb77e54fa13175258
# ✅ Saved block with hash 'c45bfc6f5da3939054a405a199df2b47c773755743364132c50ce636fdd8d0e3' to MongoDB.
# ✅ Added image '1 (1125).jpg' to blockchain.
# 🔍 Hash for '1 (1126).jpg': 4d299246fd7e91659da886adaf7c9db534cec0aa6bb8ae1e83cafa7ac4e463c6
# ✅ Saved block with hash '144f15c22a1c9f8e992cdbf17f5affe453be1481f2159aa1f05a57b9aa77a0f2' to MongoDB.
# ✅ Added image '1 (1126).jpg' to blockchain.
# 🔍 Hash for '1 (1127).jpg': e3b12f0baf8fc45e3099512a970b60944f81000b9c0fad2212c927de0d052e31
# ✅ Saved block with hash '1b1bef4b20004c457a74854edd615f5965e3fa2228e3c66f3fb1864c5d6947ce' to MongoDB.
# ✅ Added image '1 (1127).jpg' to blockchain.
# 🔍 Hash for '1 (1128).jpg': e3e67979547ee43da14cc7900ac36a4ff0c6709c42864cd75f1b295a94492274
# ✅ Saved block with hash '457df44e4cd3ca8d6506d5cd957edb26d480aa4ba016b4743be9c4e220de870a' to MongoDB.
# ✅ Added image '1 (1128).jpg' to blockchain.
# 🔍 Hash for '1 (1129).jpg': db79c7ca675d73d04f6c8a26df720a0e7506c2bec86806be871dddb48b382004
# ✅ Saved block with hash '1c210d1e0cb8d24f939478dd87b461ee9802d7ec568fc5a75fd87da3b641286a' to MongoDB.
# ✅ Added image '1 (1129).jpg' to blockchain.
# 🔍 Hash for '1 (113).jpg': 5c5cd70b22c1adc6a5db6ed3bd4b434e08f2a31bac1f3867a8d8e37917cde1f0
# ✅ Saved block with hash '935f52b2b8d8853e441dd8a655664943328cdb36317b693631a68ef6904db2db' to MongoDB.
# ✅ Added image '1 (113).jpg' to blockchain.
# 🔍 Hash for '1 (113).png': 75e8fa24ec82ed3ab5c15914c0443651f36f68d6d31169032e7181dc9b18e690
# ✅ Saved block with hash '64037288a04373f550d3c889425c3ce64d3f062b5da176e2183907df7f2a7423' to MongoDB.
# ✅ Added image '1 (113).png' to blockchain.
# 🔍 Hash for '1 (1130).jpg': 7e59274e0bb1e2c4fe0199c128fe43672600246d9668c69105e363c3d6b8dfde
# ✅ Saved block with hash '4673827a52a45b9277e125ecf71dfd4343ffadc4d8e8c9a304d72827bef41ee9' to MongoDB.
# ✅ Added image '1 (1130).jpg' to blockchain.
# 🔍 Hash for '1 (1131).jpg': c91f307d15bca4b3bca91257b4ddfbbf623c944daf147f683661efc4be56df8a
# ✅ Saved block with hash 'c55d70a021b6939507837ffea6220110743fb7f1d29b15f9c83ea907ba009e20' to MongoDB.
# ✅ Added image '1 (1131).jpg' to blockchain.
# 🔍 Hash for '1 (1132).jpg': ce9f6fe55b7f9ad3bcc311352657751992ea5401aa2b51147c0636468bcfb085
# ✅ Saved block with hash '9cd4ece9755e8d4a0121587b6b77b3deba6b3e9bdec9e12fac0a63485da49aec' to MongoDB.
# ✅ Added image '1 (1132).jpg' to blockchain.
# 🔍 Hash for '1 (1133).jpg': a686eb8e7f180f1d420fa09ca5946834dc72735b190e8901107f7e6a1efcce3b
# ✅ Saved block with hash '6b2919126491615e42d218b7206b04042f6ae60664db60fd34743abe4575b9f4' to MongoDB.
# ✅ Added image '1 (1133).jpg' to blockchain.
# 🔍 Hash for '1 (1134).jpg': 868a2ff1aac52d5374ab998b74f9abf026bc9dddb3d8765e1ee1658987bf9cbf
# ✅ Saved block with hash 'baf56eb7555feb93e5908892935b0cef38d03a0fc1aefc8a9555228c2ec556b9' to MongoDB.
# ✅ Added image '1 (1134).jpg' to blockchain.
# 🔍 Hash for '1 (1135).jpg': f347579433fde00093680160c89056ce5b0c4d7354cd7d2a848b5baecd778791
# ✅ Saved block with hash 'bb7e4b66e17ae7f6af2e86bbe1b8c422bfd872381a72916232e54e30c9d37b9e' to MongoDB.
# ✅ Added image '1 (1135).jpg' to blockchain.
# 🔍 Hash for '1 (1136).jpg': 3273913342f9c035e6e9f3027cd5b98c35cc4a869992a47cfe363da580b73608
# ✅ Saved block with hash '465e120e9a3bfcc04ead7be9bbc770b2b835450182e3ce2b653975869a0d750c' to MongoDB.
# ✅ Added image '1 (1136).jpg' to blockchain.
# 🔍 Hash for '1 (1137).jpg': b2b92fe853d2120503f91dbf40d0510759cfee6a256c29b34b9d25f6997b0a7f
# ✅ Saved block with hash 'd2465ffdc1ee9994284c394449ceb567f568a0714d0aeca19d980644638eedf2' to MongoDB.
# ✅ Added image '1 (1137).jpg' to blockchain.
# 🔍 Hash for '1 (1138).jpg': 647ffb50ea2b4f85c5533ebd6cd613536012d2d650caf4db4d6b981c4a062156
# ✅ Saved block with hash 'c0969d38d19ebab3109028bdd4759de32277ef2b17a5c02d1a2adabd61c05b23' to MongoDB.
# ✅ Added image '1 (1138).jpg' to blockchain.
# 🔍 Hash for '1 (1139).jpg': dfc7a628b742e52b08da8203e055b096eae467783b7686814a9faf8d228b7dd0
# ✅ Saved block with hash '75400c0cf1ba375981b93c9cf25e9f9bc1768e0c711fb5923381f1d15aee8963' to MongoDB.
# ✅ Added image '1 (1139).jpg' to blockchain.
# 🔍 Hash for '1 (114).jpg': 3cb8c7b2a392b1076c0c634c9239cc27dd2fae500bf01bc43e11d6e51613f607
# ✅ Saved block with hash '9440df43bff5b18d9a3e1681d4ad0215c639b2b0a9008e97505630cf3259fbf6' to MongoDB.
# ✅ Added image '1 (114).jpg' to blockchain.
# 🔍 Hash for '1 (114).png': e5d608156e75351838ea3c545ec1cc367bf26c8c9e6889be53436d9e055c7e24
# ✅ Saved block with hash 'b7168c778c69478cafa9061c61dbca384b4f7d8b3df97cd216fbaa4933b4c335' to MongoDB.
# ✅ Added image '1 (114).png' to blockchain.
# 🔍 Hash for '1 (1140).jpg': 7c6372c01eec74d54d290f41489cf9479e0c943b00d95d2bd787c7c3a9b2626b
# ✅ Saved block with hash 'cd0fb0c469d6a3933e1896126ae4a025b954d6ff301735b774048b8822a00045' to MongoDB.
# ✅ Added image '1 (1140).jpg' to blockchain.
# 🔍 Hash for '1 (1141).jpg': cb3e7016e3d60f2fec4636a1eae7b14817ae727877538e54ff9455ea88f89b0e
# ✅ Saved block with hash '23d230b6dd9b25c234834a27f16d4318a1bffe3c8168a6bf1ff5483d04558297' to MongoDB.
# ✅ Added image '1 (1141).jpg' to blockchain.
# 🔍 Hash for '1 (1142).jpg': 62b9f71d80746854d5d57c76c7b25cf10c3fc527bb31fb6d2e4dbb1a18bc8be8
# ✅ Saved block with hash '6f15e95a660e43f5bc6ec09a86dec001afdd180fae3fbda22373b3a739617b8b' to MongoDB.
# ✅ Added image '1 (1142).jpg' to blockchain.
# 🔍 Hash for '1 (1143).jpg': 8eb0f3a7c6248d3a3b095395cc07cd7cd67109acb6fc534cefb96c010097b0b3
# ✅ Saved block with hash 'd9e58c29539b94f3aec092bb29f0cfac33e3b0cb6a1abed62e1c9361c68e2a98' to MongoDB.
# ✅ Added image '1 (1143).jpg' to blockchain.
# 🔍 Hash for '1 (1144).jpg': ce5102992b51d3837fcc22a7f3540e184a0d1b340ac13371e053145fc3790024
# ✅ Saved block with hash '2f21eb32c1c6b0440256ae5e233ba754de6d41a1fa3ef07ebce72293edd07e72' to MongoDB.
# ✅ Added image '1 (1144).jpg' to blockchain.
# 🔍 Hash for '1 (1145).jpg': 0cbfa801608fe4f056680427741ad84e497635156f5c14a36080b9a216d31217
# ✅ Saved block with hash '919c996c5b30432b04609be223efd2ccdf064c5f06dabb74b5bca8669add7f19' to MongoDB.
# ✅ Added image '1 (1145).jpg' to blockchain.
# 🔍 Hash for '1 (1146).jpg': bb899d5a83135a8bd64a80df4440f49e75b178fae4408744f24e5baa6dab5bcb
# ✅ Saved block with hash '315b31016d3d83b54cf192716a41b86cb75fa1be7ea2a00a03412f54da33a97d' to MongoDB.
# ✅ Added image '1 (1146).jpg' to blockchain.
# 🔍 Hash for '1 (1147).jpg': 02e80cd4d4849b45385279a434dbc0ec937d14cb320ad5c10e5ca0e2b609fc4e
# ✅ Saved block with hash '01485b63d3b0d7be1f8942c346acd54ad9091ae99a74bacba44c97554589ff54' to MongoDB.
# ✅ Added image '1 (1147).jpg' to blockchain.
# 🔍 Hash for '1 (1148).jpg': 7cfedf3da3a859a841b184466ffda51b7b72d2340142db47d7f73e9b15c85050
# ✅ Saved block with hash '16dee7d55acdc40b898442df820bb91f8f3eb44a70ad868dac3eeac4f4062145' to MongoDB.
# ✅ Added image '1 (1148).jpg' to blockchain.
# 🔍 Hash for '1 (1149).jpg': 77f13f6ebcc8cc2de6277bb51d7a88e09bde54d4b72cd178418fdaa82fbe4c38
# ✅ Saved block with hash '861acdf9441848e7f3314e8770ce677ecb2f59a72d5bac6153b8905bf7bc04a5' to MongoDB.
# ✅ Added image '1 (1149).jpg' to blockchain.
# 🔍 Hash for '1 (115).jpg': ec509a4ee7cb8e7a360a48055143fdaf896f30c8c35033d001a886b250279aab
# ✅ Saved block with hash '6d1a7cb86b0f17b5f5f29522c0cb6c5561935a0c0b06e7314eb921802c9a2fd6' to MongoDB.
# ✅ Added image '1 (115).jpg' to blockchain.
# 🔍 Hash for '1 (115).png': 78889c5774c29dbc9c94fa8ddca2519ba83392db51e49f6661848d1ad082bba4
# ✅ Saved block with hash '448e761efb60b432fa7e632af200f51afde12e89f433acbdc9e8444175c33942' to MongoDB.
# ✅ Added image '1 (115).png' to blockchain.
# 🔍 Hash for '1 (1150).jpg': 0ecff839f446615efcb294912fa5bfbf9c5c5c59b878de4ae176d4223b2ab0eb
# ✅ Saved block with hash '1d7bd029341e2432424a8caa618c48f2e54890959367c948d2c5151329ef43da' to MongoDB.
# ✅ Added image '1 (1150).jpg' to blockchain.
# 🔍 Hash for '1 (1151).jpg': 94d7d86e98d5667828d47a82c1aff04c1bef2c0512f2e6bc937038e1f03a7e9a
# ✅ Saved block with hash 'f00e9b1a2fb99c11e37105990aa9dce8ddfc62f659e62e3aa258fd7d9e80665b' to MongoDB.
# ✅ Added image '1 (1151).jpg' to blockchain.
# 🔍 Hash for '1 (1152).jpg': 097631c8e6ec64f9e34f71385e1da7133c927553881c9f8a5c4878f297303584
# ✅ Saved block with hash '439266a28917e8de0271056d1b3998b7683c3080f432ec342835c66abc79ef14' to MongoDB.
# ✅ Added image '1 (1152).jpg' to blockchain.
# 🔍 Hash for '1 (1153).jpg': dbfdc7d8530604889a6a2cf5a3d3f63927bcc3f2b991cec65bb6cdb2f29f88e0
# ✅ Saved block with hash '7aef20e1b33c25d5db6c44d62d9a87332c4e7c27d50d0fadb66518d128bab5f7' to MongoDB.
# ✅ Added image '1 (1153).jpg' to blockchain.
# 🔍 Hash for '1 (1154).jpg': 0015e82b4b9baf7b2fb7a3a46315e423cba5ec804627dd3e1af6514238470d2e
# ✅ Saved block with hash '1d646ad4490194bcd4cef72c61407520eb15babf101bc2b8843395022832cb2b' to MongoDB.
# ✅ Added image '1 (1154).jpg' to blockchain.
# 🔍 Hash for '1 (1155).jpg': 5400501286406d3dc150d3e78c6840f7b0cedf11c8ada9b526e78fe5904ac5b5
# ✅ Saved block with hash 'e6a4dee1ac1968d01a644d3d559d3d9f4b203ca1d025a3c1430a2acf785492b3' to MongoDB.
# ✅ Added image '1 (1155).jpg' to blockchain.
# 🔍 Hash for '1 (1156).jpg': cbf8408e96aa88ebae3f48e2957597b24d89138b6c07e888b9b2884d1f13d6ce
# ✅ Saved block with hash 'f42a1e7170044ad0a3bd73688e5a6de8cf70e99ae7f27aa2f22c3ccde2439505' to MongoDB.
# ✅ Added image '1 (1156).jpg' to blockchain.
# 🔍 Hash for '1 (1157).jpg': 7d677b77b10b116c30713b4c61205099a96b52f2ca58282fa8d51486bb653d36
# ✅ Saved block with hash '220b94187cb6aae9a99c07d87aa12ad09e9a92b1e2cc7f14d42cc911a37e52b4' to MongoDB.
# ✅ Added image '1 (1157).jpg' to blockchain.
# 🔍 Hash for '1 (1158).jpg': 5fd220f44d9446d523f67b7f454df9c086ee40bc0a34b9e88fad171b4d047eb8
# ✅ Saved block with hash 'a3b079c8175a5ac5fd1470bcb828e553aecb503a1262cc4ee710c0b6fbb9e302' to MongoDB.
# ✅ Added image '1 (1158).jpg' to blockchain.
# 🔍 Hash for '1 (1159).jpg': eaf9d8518c7a77a18e1e7dbe346cfb55976e05ad58164adff249fb806c9d3e0a
# ...
# ✅ Added image '1 (943).jpg' to blockchain.
# 🔍 Hash for '1 (944).jpg': 0a47231bd1bd4d26f68dc93d912c62b8b32eb1273e2da5aa7a0504b5fdca030a
# ✅ Saved block with hash '25190a41d99e7be9f86e38a37c37b5c49a29b87b71ead6443727d7cffbf857b3' to MongoDB.
# ✅ Added image '1 (944).jpg' to blockchain.
# 🔍 Hash for '1 (945).jpg': fcd39f2eeb65b52371b2338713fd6586e2a668d13e37fdc1c8288f7e7f4cb000
# ✅ Saved block with hash '934bad1cdfe02340af8a2d9fbb1e3f4239a396b2e95caf333beab7960bfe7d48' to MongoDB.
# ✅ Added image '1 (945).jpg' to blockchain.
# 🔍 Hash for '1 (946).jpg': d0cae1ed111274e430d2574ba066ae05831b77ca216ae045d8883d2aefa01576
# ✅ Saved block with hash '27acfe9f0745f8b7e7b4fadc838f359da8d3583781e29590b40dd7bbce33c4eb' to MongoDB.
# ✅ Added image '1 (946).jpg' to blockchain.
# 🔍 Hash for '1 (947).jpg': 48860eec0bd7045f34b3040b3a76a385564eb287becb2080bfafe066bac4cc65
# ✅ Saved block with hash '03f7e08e4db4490f80234408030c19f274aaa0848ecebdd532db033a859ccb9e' to MongoDB.
# ✅ Added image '1 (947).jpg' to blockchain.
# 🔍 Hash for '1 (948).jpg': e16a8d690765fb25c12bc19de6235954d49314546eb6f3015f6f42133c6bc6c6
# ✅ Saved block with hash '49599d7504acde3933f95c95a316e01a2240e81fbfe0ceffec5b943864200c4f' to MongoDB.
# ✅ Added image '1 (948).jpg' to blockchain.
# 🔍 Hash for '1 (949).jpg': c441036764509914ca90927d2a21da2d9def273d9aa557c3265a09800967d5ee
# ✅ Saved block with hash '22797a8683f926fc4b76d41c0c1776e6b8b07739595267a1b468d2c17882c64d' to MongoDB.
# ✅ Added image '1 (949).jpg' to blockchain.
# 🔍 Hash for '1 (95).jpg': a6c1ccecc39c3dc001a6ab86639284fd61d19b0533d382fc44297846e2ceb029
# ✅ Saved block with hash '34946bbc1ceeed9da7883f7dc9c5b5f54f4e37ce3fc44e7854266dacb319d9bf' to MongoDB.
# ✅ Added image '1 (95).jpg' to blockchain.
# 🔍 Hash for '1 (95).png': 44538a28671f31b87a9716e31496ba4a321dbffd062e5ec8d12518f7c9b759a2
# ✅ Saved block with hash 'a60fe542086e77bf34734baab324d6f8ed514f90f28d698397d2cc590e97d1d3' to MongoDB.
# ✅ Added image '1 (95).png' to blockchain.
# 🔍 Hash for '1 (950).jpg': f765ad4ecc57ea85ba9070a48d193907bda52c207dbd0969d329ba43e98d7554
# ✅ Saved block with hash 'd07d63dedf94ef4109183be45bac7011a0fc0e5b82508df7330c04a52f43c214' to MongoDB.
# ✅ Added image '1 (950).jpg' to blockchain.
# 🔍 Hash for '1 (951).jpg': da0ceecb6f1ca68bf995813423dd6b56f66c54abac2009d6f9c27d1c7114adf9
# ✅ Saved block with hash 'c28e9587b5245a2660b3cc72400bac92915f52cdb86adf37682c3e771ce19eef' to MongoDB.
# ✅ Added image '1 (951).jpg' to blockchain.
# 🔍 Hash for '1 (952).jpg': b44306fd26d275223682ed6790871f85aa8db3d5967aa7c4b59a6ea80619c064
# ✅ Saved block with hash 'bd1a7a6769b260e82b5055622a353b24d898a6f4b63584b70a870603bf2d216a' to MongoDB.
# ✅ Added image '1 (952).jpg' to blockchain.
# 🔍 Hash for '1 (953).jpg': e470bbe3d25c5458060feee028a1c3eb77bc460b02d838ac44eb7b3413ac54fc
# ✅ Saved block with hash '6ea2ec0f2f0dfe2c9a0ddcdf2110be981261b7349f59b80d30c3e18f0afb67c4' to MongoDB.
# ✅ Added image '1 (953).jpg' to blockchain.
# 🔍 Hash for '1 (954).jpg': 8fa1a3d3ee9f7a2afb56a999efb1069414cf2ed110198ac37670edfc807acba5
# ✅ Saved block with hash 'f8cf56e34fec8538657fa5c128bf9ff5e947c14bc94fc142dad99662760f9fd0' to MongoDB.
# ✅ Added image '1 (954).jpg' to blockchain.
# 🔍 Hash for '1 (955).jpg': a697c9ea068009e06dd6ba9ece55cd6dbdecff112d37dded173cbcb7382a7fb8
# ✅ Saved block with hash '012819a2828423e984337e127a8b4d8de93d6101aa505d0b20ea373a0211be91' to MongoDB.
# ✅ Added image '1 (955).jpg' to blockchain.
# 🔍 Hash for '1 (956).jpg': 30dcf6377ab5ba5d43ef818ad5415eb466651064f85096e0b8435e2e02472da5
# ✅ Saved block with hash 'bd5e23d1d207172f545373cfe929d9d051e745e53314177eb6e8125304bcefd4' to MongoDB.
# ✅ Added image '1 (956).jpg' to blockchain.
# 🔍 Hash for '1 (957).jpg': 41038d73795f21b2c4579154bf58563960e30cffa097cadf0d2cf99acb9e1ba3
# ✅ Saved block with hash '48586e300c162bff010451837829995072ded73e25f2a981251ec9d569d23bfe' to MongoDB.
# ✅ Added image '1 (957).jpg' to blockchain.
# 🔍 Hash for '1 (958).jpg': 6b4f9cd1fd753997c49b76d7724c4814a426d32471cd7d50fbfee1ef249dde19
# ✅ Saved block with hash '80f6d81fd5c2dc064d67a57ac0c94e1f87575ad49a0e8f93c45cd6c7737c0d9f' to MongoDB.
# ✅ Added image '1 (958).jpg' to blockchain.
# 🔍 Hash for '1 (959).jpg': a3d001ab47406365e6f056eb7dc847e00fa1714568ad330338870e3060945151
# ✅ Saved block with hash 'c183b3479e8da207c2c4d161a223cfbd5d7d5157a1a22714494dd76cdb0e0ab3' to MongoDB.
# ✅ Added image '1 (959).jpg' to blockchain.
# 🔍 Hash for '1 (96).jpg': e22f0f8e52add0dc32eb2d82f6a96ee0e0d5e3c284f278cd45c532a77643c559
# ✅ Saved block with hash 'c6bfa049721bdd535d028b9a47d85d7b6f440d974757e87621c62a5130089c80' to MongoDB.
# ✅ Added image '1 (96).jpg' to blockchain.
# 🔍 Hash for '1 (96).png': 1ada7e4941d0028565f50bc5f380a9f0fdf70daedd15b019eccb520118868e3f
# ✅ Saved block with hash '30c3b0378b0b4df1916a93bd712db8eec9bc3daabe7f719eec4a718566bc9aad' to MongoDB.
# ✅ Added image '1 (96).png' to blockchain.
# 🔍 Hash for '1 (960).jpg': c09b49cbce2d1db14d4e697933e14d832509471cb81248d99c292f92262bbbb7
# ✅ Saved block with hash '90ae57169b708e35b888c16a6f7c6e269db33c63607a2003092b28fdfe9378c0' to MongoDB.
# ✅ Added image '1 (960).jpg' to blockchain.
# 🔍 Hash for '1 (961).jpg': d4719b18e819693987ddc7863dfe405f5c766ec144b6e53cc7bbc72ed7b537f8
# ✅ Saved block with hash 'cba8d31382dc9e697215e5ce0cd41d64c19cadaba838508f8038fbde375f7c31' to MongoDB.
# ✅ Added image '1 (961).jpg' to blockchain.
# 🔍 Hash for '1 (962).jpg': bb73ac423e36ad00a12fddb4e35a95b08ce674a229d347009068d94f5f23ce4b
# ✅ Saved block with hash '54f53e77107aed4271c9857a40df4b3e7e6aae447820cd99dedd83e13c132f3f' to MongoDB.
# ✅ Added image '1 (962).jpg' to blockchain.
# 🔍 Hash for '1 (963).jpg': a1f1bec41a1df4d0ff2016b68d5a074ad7ace4dfa08af17ecdf71820a8735842
# ✅ Saved block with hash 'a78b0cea2617a519d90842f897b98d25d0ec2814a251a702c0a00718318b937a' to MongoDB.
# ✅ Added image '1 (963).jpg' to blockchain.
# 🔍 Hash for '1 (964).jpg': e26eed02d9b527e7daf8a3b6bd46ef9c5e11188240ab181a9f3ee742568a31d1
# ✅ Saved block with hash 'a1eff669abfa6dc1edff341707b3282e3537515729ca72ebe5583c393404fb81' to MongoDB.
# ✅ Added image '1 (964).jpg' to blockchain.
# 🔍 Hash for '1 (965).jpg': 295b069dd04348a249ff83c8735cd34928c4c122c14be37604d77774801a5fb1
# ✅ Saved block with hash 'd7cdcf971ab1ad43c06628f8357df60e4832af4cdd417ec0ab826ece3c64756e' to MongoDB.
# ✅ Added image '1 (965).jpg' to blockchain.
# 🔍 Hash for '1 (966).jpg': 793b4af68f6741b56a0ccc9ff020b49d372f793ac38b964bb8c575bfc1bfa3c3
# ✅ Saved block with hash 'e54fd5990758b7df745f754a5a99593d19a712293c3155aabbef122a4c12e010' to MongoDB.
# ✅ Added image '1 (966).jpg' to blockchain.
# 🔍 Hash for '1 (967).jpg': 2120605bcc347048be0dfec980839fb6ec0be61d519bb08b58d222d08af0f06c
# ✅ Saved block with hash '6347456a5c6ca0c46285116130c18971bc5b725c06cf7859c008f47f3f86803c' to MongoDB.
# ✅ Added image '1 (967).jpg' to blockchain.
# 🔍 Hash for '1 (968).jpg': 8c887ba1d07214246fe74c97586d7c542acb50c23c767eb102e4bfcf542a9e47
# ✅ Saved block with hash 'c8dd596a107c3ebc855c4cf478effdd3c8195754421e62bc51ffb2cad3edd33e' to MongoDB.
# ✅ Added image '1 (968).jpg' to blockchain.
# 🔍 Hash for '1 (969).jpg': 72ef5677744bacdd5446d4c9f0049a120cadefb3ed30b6b78843475edbd141c3
# ✅ Saved block with hash '463a290abeb0a420e7359908148b44992f6fa6097fe7aa618a984a4ab05267ca' to MongoDB.
# ✅ Added image '1 (969).jpg' to blockchain.
# 🔍 Hash for '1 (97).jpg': 67e427447bb03d5b8da47166e0fa58ca67531c25442b8e5a3448fb8bb3e3b1f3
# ✅ Saved block with hash '337c0fe2e5ac1911d4f8aed57f08f18c9dfe51d79aab8a60ad938127c40b6446' to MongoDB.
# ✅ Added image '1 (97).jpg' to blockchain.
# 🔍 Hash for '1 (97).png': 2c3c3277a29a0e8a2c432623bd1c1ce90c14a59c911dad2058f36b91f24f883b
# ✅ Saved block with hash '49092385f608d1651f265b110d23da603ab07f387dbbc6001ae1fe8b4734eb82' to MongoDB.
# ✅ Added image '1 (97).png' to blockchain.
# 🔍 Hash for '1 (970).jpg': f5128be0af2318d264319b67de26e1db29b15d60d6055888d7006f8e29c6a059
# ✅ Saved block with hash '57bbf56664bcb641044f4e120f885c5038b8c7fcb4baa19b0f8bbe1553370468' to MongoDB.
# ✅ Added image '1 (970).jpg' to blockchain.
# 🔍 Hash for '1 (971).jpg': 4d299246fd7e91659da886adaf7c9db534cec0aa6bb8ae1e83cafa7ac4e463c6
# ✅ Saved block with hash 'bbd66f10c1c582fcf4b831483d0d7ddc536d60c73796ef1e4e2e29f3bad8cab1' to MongoDB.
# ✅ Added image '1 (971).jpg' to blockchain.
# 🔍 Hash for '1 (972).jpg': e8867961a73b5dde89f1976a27a3ed4576c1cfb4dee23fd5c6ad5964824f3af7
# ✅ Saved block with hash 'd37f2cacd1c941a97dbd922c67087050f59c7bda6f0e4eccd33865394166743c' to MongoDB.
# ✅ Added image '1 (972).jpg' to blockchain.
# 🔍 Hash for '1 (973).jpg': 8a34e7110637bd47315f85bc7edfbc55165d6513a3378306ea6118d8d020681a
# ✅ Saved block with hash 'bad0f714114bf90584cb6720fbdda77e373feccfa698e95affaedcb968682d2e' to MongoDB.
# ✅ Added image '1 (973).jpg' to blockchain.
# 🔍 Hash for '1 (974).jpg': 1bb53060138a66955866c4823399677a97039b9d09455c6d52305f0c77e1ec0a
# ✅ Saved block with hash '7115b76069125a4a52927dd0ec0bab8b7138f290c73d78ddd79042a75e6a9856' to MongoDB.
# ✅ Added image '1 (974).jpg' to blockchain.
# 🔍 Hash for '1 (975).jpg': 923c34b34dc907b41556d049080ab698520b5f1d1cb408f596298b31097aae40
# ✅ Saved block with hash '6f143ee95d050fed453a97a30f3ba01b7f6f81c9f46d72e24a6f0fddccb31278' to MongoDB.
# ✅ Added image '1 (975).jpg' to blockchain.
# 🔍 Hash for '1 (976).jpg': f4d4b3fcb53f94e7a5c1c2b7aa86a0a1051e0f22e3b26e9e5025762de14959d5
# ✅ Saved block with hash '275b3c55269cf096248462f754c2bb69d34ae4c1368175ee3f4a85d672165bd0' to MongoDB.
# ✅ Added image '1 (976).jpg' to blockchain.
# 🔍 Hash for '1 (977).jpg': ed8e3ebef6eb069eb077ee82e6a1a85cc9465ff5cc920f87887a7bca77744306
# ✅ Saved block with hash '9adb93b4fbed32ebcba5aaac45acc454bbbb9dc35dea33d63a5dae7ad13423f2' to MongoDB.
# ✅ Added image '1 (977).jpg' to blockchain.
# 🔍 Hash for '1 (978).jpg': 3a3a1379267c68919bfe45d7140c66efaf4818f2d4f98e257acbab50e7df56aa
# ✅ Saved block with hash '4806ec549d8677900117c2fff048b9d623c9220d7b985994b35c6b7445c4d23d' to MongoDB.
# ✅ Added image '1 (978).jpg' to blockchain.
# 🔍 Hash for '1 (979).jpg': 7f72b82cbc908b3dc27eead22cfa3430c146274f2beb8c1194cd87bd8dce4abf
# ✅ Saved block with hash '177136da52982c00a6d944703e0548698cf11d4959af2550d93ed1464cabc0e2' to MongoDB.
# ✅ Added image '1 (979).jpg' to blockchain.
# 🔍 Hash for '1 (98).jpg': 04527fcfe3b17c3df20608a7e2cb5857f907c5ac36b42a3a9b24b01bb1116c9b
# ✅ Saved block with hash '3a1b1131bcca35f455144316627f55e5aa6d5add53124b17663cd4ceb1014876' to MongoDB.
# ✅ Added image '1 (98).jpg' to blockchain.
# 🔍 Hash for '1 (98).png': 700c3af705c5515239d3d86b650d53c329874aa51bf99c9c4e42d6bd0df5a159
# ✅ Saved block with hash '7fbf62f70fb58bf7c9e66393f75056e5b99035b467c0b0019694a9c188a3f33e' to MongoDB.
# ✅ Added image '1 (98).png' to blockchain.
# 🔍 Hash for '1 (980).jpg': 62a6eeb75830fc2439296b119ac5e6713ec067002125b186105c97fc6eb68a9c
# ✅ Saved block with hash '2ca6876244c1bee96529146f9d0fc92e6b6487dc182ec45365ce615ff00be8b1' to MongoDB.
# ✅ Added image '1 (980).jpg' to blockchain.
# 🔍 Hash for '1 (981).jpg': f2c1607a3427dcf76c8b8489cb116c5c32397e738b940ed78227f0b1512cbd49
# ✅ Saved block with hash '15be2206b90fbb5636078e6f2e0f7b90aa9ba7faeec316aaf6448b46fbdea1c8' to MongoDB.
# ✅ Added image '1 (981).jpg' to blockchain.
# 🔍 Hash for '1 (982).jpg': 8e5e995e610f0841a5f63b218cd8614719992a1bdf7513d1121f9898e8ded546
# ✅ Saved block with hash '2284be299e94e22ac75fffc83c006beb1cc56dadaddea0ca7c648bf133863023' to MongoDB.
# ✅ Added image '1 (982).jpg' to blockchain.
# 🔍 Hash for '1 (983).jpg': e4acc29d88a2c6982fe295b50109e4c4c50be93f31bdcedbdf26b783b406efb6
# ✅ Saved block with hash '86e55b53a580e4296336bc93c4bd5fa39370b514687f2512b8eca1d48ebf0dae' to MongoDB.
# ✅ Added image '1 (983).jpg' to blockchain.
# 🔍 Hash for '1 (984).jpg': a07d195a748624fbd381f633137cf2579c3784795bf5ef7a48437f408733ae46
# ✅ Saved block with hash '3d849c9a03b5f6dff2f4e302506681d2aafee2686411885ab95a3a8780a702ea' to MongoDB.
# ✅ Added image '1 (984).jpg' to blockchain.
# 🔍 Hash for '1 (985).jpg': 768896bd37911b7b8828327d806b7380e3c5f90dcd579855dab81acd5eb1a4d0
# ✅ Saved block with hash '62a223a4133e19f1eec55b24340afb9cc892141286c82e6ee67526f91c94dc0d' to MongoDB.
# ✅ Added image '1 (985).jpg' to blockchain.
# 🔍 Hash for '1 (986).jpg': eb7b97305ba15e8471684a710aa8ad9d509775bb1d130bbd25a5abe746f915cd
# ✅ Saved block with hash '0da4d0e0940228be6dd17aa0f6da20d18bdddcc467eac3da260c50d80d0e43d0' to MongoDB.
# ✅ Added image '1 (986).jpg' to blockchain.
# 🔍 Hash for '1 (987).jpg': aae54e572db85dfa80257da2e18a6d87b00c1f998a43a0bb434c41280f5d4d9e
# ✅ Saved block with hash '064005d610185c77b48aa741022a7c717af7c2bfdbced8af6e90cdc857c7d2c8' to MongoDB.
# ✅ Added image '1 (987).jpg' to blockchain.
# 🔍 Hash for '1 (988).jpg': 6226310f0020448cec124e64b58239abffb1388cced9ae74dfd8e9b65527a059
# ✅ Saved block with hash '2ad32eb21db36830018635567567a5072c6e674ebee24ba83238bf413f51cad7' to MongoDB.
# ✅ Added image '1 (988).jpg' to blockchain.
# 🔍 Hash for '1 (989).jpg': dfc7a628b742e52b08da8203e055b096eae467783b7686814a9faf8d228b7dd0
# ✅ Saved block with hash 'ee75ed24ab0c34562b6f0466baefbfd790fa4f77dc48fecca262b0417b80ef3e' to MongoDB.
# ✅ Added image '1 (989).jpg' to blockchain.
# 🔍 Hash for '1 (99).jpg': 0e7282d1efc0e288127e78fadb88c79c9efc1289d623ae5820e40f93b2777a0d
# ✅ Saved block with hash '48e7d86492b19efc33bdc73a6c0de10b27f68e8bc031ab6506c74c883cc92110' to MongoDB.
# ✅ Added image '1 (99).jpg' to blockchain.
# 🔍 Hash for '1 (99).png': 7f4181ff68239999302e9bafe7ee5f92b8c39a5049c654d33abb93133fb623dc
# ✅ Saved block with hash 'efae4301848bcd1b3975940a77ee22e50fcecbe097e97889817e883b27aa6a44' to MongoDB.
# ✅ Added image '1 (99).png' to blockchain.
# 🔍 Hash for '1 (990).jpg': 384bfb2faa78ea128fe7b1e750838db1ab66c282683a7e29a42d2ef40346d718
# ✅ Saved block with hash 'f81cead3b4d8dd06cf383fb127281a7a7a8883fd8b6ec49a8744ce78cb8c7b38' to MongoDB.
# ✅ Added image '1 (990).jpg' to blockchain.
# 🔍 Hash for '1 (991).jpg': 000378c1d10174b464cce1529565dbc5fc9a0d45d4d175cd88ee075bd6ecde6e
# ✅ Saved block with hash 'e2cd08056d1d05f9e47d073af3aaf2cc35565cdb4271ba2b788bac2fd596f2d8' to MongoDB.
# ✅ Added image '1 (991).jpg' to blockchain.
# 🔍 Hash for '1 (992).jpg': 12276baf86140bdd5a2b09b352e8dc29b0d90c5efc27bd28ecd68ad6cfa58c46
# ✅ Saved block with hash 'fc54a1dab8a9229719b5ab31ba3af99074188eeee99d7e02808384351cdf57ed' to MongoDB.
# ✅ Added image '1 (992).jpg' to blockchain.
# 🔍 Hash for '1 (993).jpg': 1d9a6fc7ebc490d81b6142721e2e88970b04743f76d68a2bc269507f4f0c24ce
# ✅ Saved block with hash 'd39ee3f4a9070d162582d7bf9a53d62accbd0c9a8a9b7ac03d3c520f699d4d34' to MongoDB.
# ✅ Added image '1 (993).jpg' to blockchain.
# 🔍 Hash for '1 (994).jpg': 4fad9873b7c4fa69ada0bf4a68ec5bd00a4349767a0152a93ed55f0334aa970a
# ✅ Saved block with hash '3ee314285e24c8641cf0a501afeb95d92446ab54e1f9673fb0dad18f0a84a776' to MongoDB.
# ✅ Added image '1 (994).jpg' to blockchain.
# 🔍 Hash for '1 (995).jpg': e01e961629adedf541f6365c56aade74e69ce02c5a97e41989a962f8878ee662
# ✅ Saved block with hash 'a3e836037e567e4f490703371258152258d6253e2b53303dffb1ff66ceb6b36b' to MongoDB.
# ✅ Added image '1 (995).jpg' to blockchain.
# 🔍 Hash for '1 (996).jpg': cc536255adc67294a44283fb8c0e370776b6bc2fe6a89c1c0cf22f4ba36577be
# ✅ Saved block with hash '94b34e20c47ba467ce440763f7c46a1eca3ad7de09acc62afdeea798f2de9f44' to MongoDB.
# ✅ Added image '1 (996).jpg' to blockchain.
# 🔍 Hash for '1 (997).jpg': 5a31148ac5a0aa123adce5f2ea828b29e8bf94d446efa7e9433c4d16128de9b7
# ✅ Saved block with hash '06b535a62b583345badcb7b31971f4fc0c1a075c7c0f571ee1516248a6b1109c' to MongoDB.
# ✅ Added image '1 (997).jpg' to blockchain.
# 🔍 Hash for '1 (998).jpg': 525d654f8ab1c93c9c8f44ae6532cb31c01491e0a20efa81fcd022904ab7ac3e
# ✅ Saved block with hash '8ee4f7482c46b21f81e6dbcf2c55e8c4e8ae1777393a2223c223aac09de0059d' to MongoDB.
# ✅ Added image '1 (998).jpg' to blockchain.
# 🔍 Hash for '1 (999).jpg': 838279eb1e749beab6f2506aaffb8c4f5d4b066a8b35c8779aa0e5a5d510f368
# ✅ Saved block with hash '472d6198569814ea4a0274941068c0b4c51816ad41c7eab5958eb45a15cf31ae' to MongoDB.
# ✅ Added image '1 (999).jpg' to blockchain.
# 🔍 Checking image: C:\Users\saniu\Machine Learning 2025\Block Chain\Humans\1 (100).jpg
# ✅ Image is verified in blockchain.
# 🔹 Owner: DatasetOwner
# 🔹 Timestamp: 2025-02-07 01:44:35
# 🔹 Description: Image: 1 (100).jpg
# ⚠ This image belongs to the given owner.
